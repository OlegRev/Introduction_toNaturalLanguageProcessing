# %%
# !wget -O imdb.zip -qq --no-check-certificate "https://drive.google.com/uc?export=download&id=1vrQ5czMHoO3pEnmofFskymXMkq_u1dPc"
# !unzip imdb.zip
# !pip -q install eli5
# !pip -q install spacy
# !python -m spacy download en
# Out:
# Archive:  imdb.zip
# replace test.tsv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace train.tsv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 4.0 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.62.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.8.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.8.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %% [markdown]
# Тут придется авторизировать запрос к гугл драйву, извините.

# %%
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded = drive.CreateFile({'id': '1d1-5FwxK53ePwygNWeG7jhsOWZbi5HOv'})
downloaded.GetContentFile('train_docs.pkl')

downloaded = drive.CreateFile({'id': '1MMOY477t965G0C5DtXeREVp0X85UaNq5'})
downloaded.GetContentFile('test_docs.pkl')

# %% [markdown]
# # Классификация текстов
#
# Начнём с самого простого - анализа тональности текста.
#
# Будем классифицировать отзывы с IMDB на положительные/отрицательные.
#
# Датасет взят с http://ai.stanford.edu/~amaas/data/sentiment/

# %%
# !head train.tsv
# Out:
# is_positive	review
# 0	"Dreamgirls, despite its fistful of Tony wins in an incredibly weak year on Broadway, has never been what one would call a jewel in the crown of stage musicals. However, that is not to say that in the right cinematic hands it could not be fleshed out and polished into something worthwhile on-screen. Unfortunately, what transfers to the screen is basically a slavishly faithful version of the stage hit with all of its inherent weaknesses intact. First, the score has never been one of the strong points of this production and the film does not change that factor. There are lots of songs (perhaps too many?), but few of them are especially memorable. The closest any come to catchy tunes are the title song and One Night Only - the much acclaimed And I Am Telling You That I Am Not Going is less a great song than it is a dramatic set piece for the character of Effie (Jennifer Hudson). The film is slick and technically well-produced, but the story and characters are surprisingly thin and lacking in any resonance. There is some interest in the opening moments, watching Jamie Foxx's Svengali-like manager manipulate his acts to the top, but that takes a back seat in the latter portion of the film, when the story conveniently tries to cast him as a villain, despite his having been right from a business stand-point for a good majority of the film. Beyonce Knowles is lovely and sings her songs perfectly well, but is stuck with a character who is basically all surface glitz. Anika Noni Rose as the third member of the Dreamgirls trio literally has nothing to do for the entire film. Eddie Murphy acquits himself well as a singer obviously based on James Brown, but the role is not especially meaty and ultimately has little impact. Foxx would seem ideal casting, but he seems oddly withdrawn and bored. The film's biggest selling point is surely former American Idol contestant/Oscar winner Jennifer Hudson in the central role of Effie White, the temperamental singer who gets booted from the group and makes a triumphant closing act return. For me, Effie has always been a big problem in both the show and the movie. The film obviously wants you to feel sorry for her and rather ham-handedly takes her side, but I have never been sure that this character deserves that kind of devotion. From the start, Effie conducts herself for the most part like an obnoxious, egotistical, self-centered diva, who is more interested in what everyone else can do for her rather than having much vested interest in the group of which she is a part. When she is booted from the group for her unprofessionalism and bad attitude, the charges are more than well-founded, but the stage show/film seem to think Effie should be cut unlimited slack simply because she has a great voice. Even though the film tries to soften some of Effie's harder edges to make her more likable, the charges still stand. Her story becomes more manipulative by suggesting she should have our further sympathy because she is an unwed mother struggling to raise her daughter - using the implication that (much like the talent card) motherhood immediately makes any behavior excusable. Indeed the only big effort the film makes to show Effie's mothering is to tell us about it and then include a scene where she barks at her daughter in the unemployment office, insists that the girl has ""no father"" and then refuse to look for gainful employment to support them since singing is all she knows. In the hands of a skillful actress, the gaps could perhaps have been remedied with technique and charisma. Unfortunately, Hudson is not that actress. She sings well, but the dialog-driven moments do not come naturally to her nor do high emotional moments. Effie's signature moment (the aforementioned And I Am Telling You... number) is well-sung by Hudson, but emotionally flat in the acting department. Effie is supposed to expressing her rage and desperation at her predicament, but Hudson comes off as a cabaret performer belting out  ...
# 0	This show comes up with interesting locations as fast as the travel channel. It is billed as reality but in actuality it is pure prime time soap opera. It's tries to use exotic locales as a facade to bring people into a phony contest & then proceeds to hook viewers on the contestants soap opera style.<br /><br />It also borrows from an early CBS game show pioneer- Beat The Clock- by inventing situations for its contestants to try & overcome. Then it rewards the winner money. If they can spice it up with a little interaction between the characters, even better. While the game format is in slow motion versus Beat The Clock- the real accomplishment of this series is to escape reality. <br /><br />This show has elements of several types of successful past programs. Reality television, hardly, but if your hooked on the contestants, locale or contest, this is your cup of tea. If your not, this entire series is as I say, drivel dripping with gravy. It is another show hiding behind the reality label which is the trend it started in 2000.<br /><br />It is slick & well produced, so it might last a while yet. After all, so do re-runs of Gilligan's Island, Green Acres, The Beverly Hillbillies & The Brady Bunch. This just doesn't employ professional actors. The intelligence level is about the same.
# 1	I simply love this movie. I also love the Ramones, so I am sorta biased to begin with in the first place. There isn't a lot of critical praise to give this film, either you like it or you don't. I think it's a great cult movie.
# 0	"Spoilers ahead if you want to call them that...<br /><br />I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...<br /><br />THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or ""effort"".<br /><br />THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of ""Woah, you totally freaked me out"" and ""I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?"". It makes me want to rip out all my hair, one strand at a time and feed it to myself.<br /><br />THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards...<br /><br />THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The ""Woah you totally freaked me out"" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone.<br /><br />TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it.<br /><br />Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it.<br /><br />Signing off... Amanda Christmas"
# 1	"My all-time favorite movie! I have seen many movies, but this one beats them all! Excelent acting, wonderful story. You will, as a ""normal"" caring person start to love George. Altough he is an actor, he is also himself and a very lovable person. And maby most important thing: you will learn to respect & look different to people with Down Syndrome."
# 1	Wonderful film, one of the best horror films of the 70s. She is realistic settings and atmospheres. As usual it was inevitable the usual negative comments. I have noticed that most horror films of a certain period many times fail to reach even sufficiency. Obviously because most horror movies are old and must be denigrati, is like a mental mechanism that moves the minds of the potential of music critics here.<br /><br />Before you read the review already knew what was the final judgment. In the film a good gift because 10 is really well done. Raines reads quite well and the film as a way in which it was produced reminds me a lot of Kubrick films. He really impression. Excellent film really. I consider a film anthology of years'70.
# 0	and shot in Vancouver with the 'mountains' of the low country of South Carolina visible in the background. For heaven's sake, they should have reset the location. There are no coastal mountains in South Carolina. Period.<br /><br />Lame visuals. They should have been beautiful. And the story limped along.<br /><br />I really don't understand why it was such a hit as a book, although I have to admit it's one I haven't read as yet. Usually I read the book and give the film a miss. There was nothing in this movie that made me want to buy the book, or even borrow it from the library.<br /><br />Verdict: The Mermaid Chair seemed pretty shallow to moi.
# 1	This is the best dub I've ever heard by Disney, as well as the best adaptation since the biggest abuse ever on soundtrack, themes, characters, dialogues in Kiki Delivery Service. Urrrghhh<br /><br />This one has different atmosphere, especially the deviation from the common heroine. This one has both hero and heroine (although I don't really endorse the use of hero & heroine here, since Miyazaki is out from the stereotype & common theme). As usual, after being introduced by Spirited away, amazed by Mononoke, troubled by Grave of Fireflies, and deeply touched by Majo no Takkyuubin , this one start with a bit doubt in my part. Wondering if this will be the first Ghibi's dud. Well, in the end just like Only Yesterday and Whisper of the Heart, I ended up giving 10 rating. I'd give 9.8 rating, but the additional 0.2 is there to share the good feeling by encouraging people to see the movie.<br /><br />SPOILER Somehow I see this as a sad movie, people die in this one, the lonely robot, the abandoned place, and it ends with destruction. It is as if mankind really can't live with too much power. The collapsing scene gave me patches of Metropolis ending. It's just sad somehow. The plot is apparent in most reviews and the soundtrack rules as well (as always). Joe Hisaishi really belongs to Uematsu, Kanno, Williams caliber.People who can brings a movie, a game, an event to life, even to be a lingering moments by astounding composition.<br /><br />This is a feel good movie that used to be part of US cinema in the classic days (It's a Wonderful Life etc etc). Well, things change....
# 1	"Linking story: another first-time viewing for me and, again, this is one of the most popular of the Amicus anthologies - and it's easy to see why, though I realize how the film's rather meaningless title could be misleading for some; I certainly fancied director Peter Duffell's choice - DEATH AND THE MAIDEN (which, incidentally, is a classical piece by Schubert that is heard in the film during the Peter Cushing episode) - a great deal more. Though the linking device itself is not all that great, the episodes are all equally compelling and enjoyable. Production values come off as very respectable indeed for the budget Duffell had to work with. The latter infuses the film with a great deal of style which is not so common with this type of film and, frankly, it makes one regret the fact that he wished to distance himself from the genre (though more so as not to be typecast rather than because he felt it was beneath him).<br /><br />Now to the individual stories themselves: <br /><br />""Method For Murder"": the opening segment does not offer any real surprises but, to make up for this, it's quietly suspenseful and appropriately creepy at times (Tom Adams' 'fictitious' villain looking like the long-lost brother of Boris Karloff from THE OLD DARK HOUSE [1932]); also, it ends with a satisfactory DIABOLIQUE-type twist, and features a fairly intense role for Denholm Elliott in the lead. That's all we need out of it, really.<br /><br />""Waxworks"": for the second story we are introduced to a curiously romantic mood which is quite unusual for this type of film; Peter Cushing and Joss Ackland are both excellent (as well as impeccably dressed) in their roles of two jilted lovers of a woman who continues to obsess them even after such a long time, and whose friendly rivalry can only lead them blindly and inexorably to a fate that is literally worse than death; an ominous hallucination scene with Peter Cushing is quite well done in view of the limited resources at hand, and Ackland's inexplicable inability - or unwillingness - to leave town somewhat recalls the house-trapped aristocrats of Bunuel's THE EXTERMINATING ANGEL (1962).<br /><br />""Sweets To The Sweet"": this is perhaps the finest episode of all - with his ambiguous role here, Christopher Lee continues to demonstrate his versatility and he is matched by an understanding Nyree Dawn Porter and the deceptive innocence of Chloe Franks (who appears as Lee's daughter). The film's treatment of the occult here is both subtle and mature, culminating in a powerful and extremely chilling 'curtain'. Trivia Note: Chloe Franks appears as a grown-up in the featurette included on the disc, and when I saw her I felt an immediate familiarity with her face but couldn't quite put my finger on it. Later, on reading her filmography, it was revealed to me that she had played one of the leads in the long-running stage adaptation of Agatha Christie's ""The Mousetrap"" in London's West End, which my brother and I were fortunate enough to catch while we there on holiday in the Summer of 2002! Needless to say, we had no idea then that she had once created such a delicate - and delicious - portrayal in sheer evil, mainly by virtue of her peculiar look and a devilish smile!! <br /><br />""The Cloak"": a wacky but oddly reverent vampire tale (that still manages to debunk many of the myths attached to the subgenre, while inventing some new ones!) which takes in some wonderful digs at exploitation cinema and, at one point, Christopher Lee himself!; Jon Pertwee is marvelous as the campy horror star who gets more than he bargained for when he attempts to bring a measure of authenticity to his work; Ingrid Pitt sends up her image nicely though her role is somewhat subsidiary to the proceedings; Geoffrey Bayldon (made up to look like Ernest Thesiger) also has a memorably quirky bit; the 'silent-cinema' style of the ending was a pretty audacious one to pull on an audience, I suppose - and, while some of the humor ...

# %%
import pandas as pd

train_df = pd.read_csv("train.tsv", delimiter="\t")
test_df = pd.read_csv("test.tsv", delimiter="\t")

print('Train size = {}'.format(len(train_df)))
print('Test size = {}'.format(len(test_df)))
# Out:
# Train size = 25000
# Test size = 25000

# %% [markdown]
# Посмотрите глазами на тексты? Какие есть зацепки, как определить, что это за сентимент?
#
# Самое простое, как всегда - найти ключевые слова.

# %%
#@title Начинаем классифицировать! { vertical-output: true, display-mode: "form" }
positive_words = 'love', 'great', 'best', 'wonderful', 'surprises', 'perfectly', 'classic', 'amazing', 'friendly', 'deserves', 'powerful', 'unusual', 'dynamic', 'nicely',  'excellent',  'strong', 'favorite', 'beautiful', 'anthology', 'individual', #@param {type:"raw"}
negative_words = 'worst', 'awful', '1/10', 'crap', 'problem', 'obnoxious',  'expecting', 'disappointed', 'dumbed', 'better', 'respectable', 'exotic', 'stereotype',  'terrible' #@param {type:"raw"}

positives_count = test_df.review.apply(lambda text: sum(word in text for word in positive_words))
negatives_count = test_df.review.apply(lambda text: sum(word in text for word in negative_words))
is_positive = positives_count > negatives_count
correct_count = (is_positive == test_df.is_positive).values.sum()

accuracy = correct_count / len(test_df)

print('Test accuracy = {:.2%}'.format(accuracy))
if accuracy > 0.71:
    from IPython.display import Image, display
    display(Image('https://s3.amazonaws.com/achgen360/t/rmmoZsub.png', width=500))
# Out:
# Test accuracy = 71.07%
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py:364: FormatterWarning: image/png formatter returned invalid type <class 'tuple'> (expected (<class 'bytes'>, <class 'str'>)) for object: <IPython.core.display.Image object>
#   FormatterWarning

# %% [markdown]
# **Задание** Придумайте хорошие ключевые слова или фразы и наберите хотя бы 71% точности на тесте (и не забудьте посмотреть на код классификации!)

# %% [markdown]
# **Задание** Кому-нибудь нравятся эти `<br /><br />`? Лично мне - нет. Напишите регулярку, которая будет их удалять

# %%
import re

pattern = re.compile('<br />')

print(train_df['review'].iloc[3])
print(pattern.subn(' ', train_df['review'].iloc[3])[0])
# Out:
# Spoilers ahead if you want to call them that...<br /><br />I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...<br /><br />THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or "effort".<br /><br />THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of "Woah, you totally freaked me out" and "I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?". It makes me want to rip out all my hair, one strand at a time and feed it to myself.<br /><br />THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards...<br /><br />THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The "Woah you totally freaked me out" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone.<br /><br />TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it.<br /><br />Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it.<br /><br />Signing off... Amanda Christmas
# Spoilers ahead if you want to call them that...  I would almost recommend this film just so people can truly see a 1/10. Where to begin, we'll start from the top...  THE STORY: Don't believe the premise - the movie has nothing to do with abandoned cars, and people finially understanding what the mysterious happenings are. It's a draub, basic, go to cabin movie with no intensity or "effort".  THE SCREENPLAY: I usually give credit to indie screenwriters, it's hard work when you are starting out...but this is crap. The story is flat - it leaves you emotionless the entire movie. The dialogue is extremely weak and predictable boasting lines of "Woah, you totally freaked me out" and "I was wondering if you'd uh...if you'd like to..uh, would you come to the cabin with me?". It makes me want to rip out all my hair, one strand at a time and feed it to myself.  THE CHARACTERS: HOLY CRAP!!!! Some have described the characters as flat, I want to take it one step further and say that they actually have a reverse character arch.. They actually start working on a parallel universe and almost start acting backwards...  THE ACTORS: Worse than the characters are the actors. They take already poor written characters and add in terrible high school drama acting. The "Woah you totally freaked me out" was said so monotone and slow - like it was dumbed down. I could complain for hours on the actors alone.  TECHNICAL: LIGHTING: An eight year old would be disappointed with lighting on this movie. Too shadowy in areas, too bleached in others. The director shouldn't use light as an emotion until he learns how to light a basic scene properly. Baby Steps! SOUND: How many sound guys does it take to make a really shotty sounding movie? 9. With that many sound guys this should sound amazing but quite the opposite has occured. There is one scene in particular that really sticks out, these guys are driving in a car and the sound of the car changes with every camera angle....WEAK! CAMERA: Learn to use it.  Anyway, I'm running out of complaining space.....rent it - I dare you...Rent it and learn from it...give it a 1 rating..it deserves it.  Signing off... Amanda Christmas

# %% [markdown]
# Применим ее:

# %%
train_df['review'] = train_df['review'].apply(lambda text: pattern.subn(' ', text)[0])
test_df['review'] = test_df['review'].apply(lambda text: pattern.subn(' ', text)[0])

# %% [markdown]
# Пора переходить к машинке!
#
# Как будем представлять текст? Проще всего - мешком слов.
#
# Заведём большой-большой словарь - список всех слов в обучающей выборке. Тогда каждое предложение можно представить в виде вектора, в котором будет записано, сколько раз встретилось каждое из возможных слов:
#
# ![bow](https://raw.githubusercontent.com/DanAnastasyev/DeepNLP-Course/master/Week%2001/Images/BOW.png)
#
# Простой и приятный способ сделать это - запихнуть тексты в `CountVectorizer`.
#
# Он имеет такую сигнатуру:
#
# ```python
# CountVectorizer(input='content', encoding='utf-8', decode_error='strict', strip_accents=None, lowercase=True, preprocessor=None, tokenizer=None, stop_words=None, token_pattern=r'(?u)\b\w\w+\b', ngram_range=(1, 1), analyzer='word', max_df=1.0, min_df=1, max_features=None, vocabulary=None, binary=False, dtype=<class ‘numpy.int64'>)
# ```
#
# Для начала обратим внимание на параметры `lowercase=True` и `max_df=1.0, min_df=1, max_features=None` - они про то, что по умолчанию все слова будут приводиться к нижнему регистру и в словарь попадут все слова, встречавшиеся в текстах.
#
# При желании можно было бы убрать слишком редкие или слишком частотные слова - пока не будем этого делать.
#
# Посмотрим на простом примере, как он будет работать:

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

dummy_data = ['The movie was excellent',
              'the movie was awful']

dummy_matrix = vectorizer.fit_transform(dummy_data)

print(dummy_matrix.toarray())
print(vectorizer.get_feature_names())
# Out:
# [[0 1 1 1 1]
#  [1 0 1 1 1]]
# ['awful', 'excellent', 'movie', 'the', 'was']

# %% [markdown]
# *Как именно vectorizer определяет границы слов? Обратите внимание на параметр `token_pattern=r'(?u)\b\w\w+\b'` - как он будет работать?*
#
# Запустим его на реальных данных:

# %%
vectorizer = CountVectorizer()
vectorizer.fit(train_df['review'].values)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %% [markdown]
# Посмотрим на слова, попавшие в словарь:

# %%
vectorizer.get_feature_names()
# Out:
# ['00',
#  '000',
#  '0000000000001',
#  '00001',
#  '00015',
#  '000s',
#  '001',
#  '003830',
#  '006',
#  '007',
#  '0079',
#  '0080',
#  '0083',
#  '0093638',
#  '00am',
#  '00pm',
#  '00s',
#  '01',
#  '01pm',
#  '02',
#  '020410',
#  '029',
#  '03',
#  '04',
#  '041',
#  '05',
#  '050',
#  '06',
#  '06th',
#  '07',
#  '08',
#  '087',
#  '089',
#  '08th',
#  '09',
#  '0f',
#  '0ne',
#  '0r',
#  '0s',
#  '10',
#  '100',
#  '1000',
#  '1000000',
#  '10000000000000',
#  '1000lb',
#  '1000s',
#  '1001',
#  '100b',
#  '100k',
#  '100m',
#  '100min',
#  '100mph',
#  '100s',
#  '100th',
#  '100x',
#  '100yards',
#  '101',
#  '101st',
#  '102',
#  '102nd',
#  '103',
#  '104',
#  '1040',
#  '1040a',
#  '1040s',
#  '105',
#  '1050',
#  '105lbs',
#  '106',
#  '106min',
#  '107',
#  '108',
#  '109',
#  '10am',
#  '10lines',
#  '10mil',
#  '10min',
#  '10minutes',
#  '10p',
#  '10pm',
#  '10s',
#  '10star',
#  '10th',
#  '10x',
#  '10yr',
#  '11',
#  '110',
#  '1100',
#  '11001001',
#  '1100ad',
#  '111',
#  '112',
#  '1138',
#  '114',
#  '1146',
#  '115',
#  '116',
#  '117',
#  '11f',
#  '11m',
#  '11th',
#  '12',
#  '120',
#  '1200',
#  '1200f',
#  '1201',
#  '1202',
#  '123',
#  '12383499143743701',
#  '125',
#  '125m',
#  '127',
#  '128',
#  '12a',
#  '12hr',
#  '12m',
#  '12mm',
#  '12s',
#  '12th',
#  '13',
#  '130',
#  '1300',
#  '1300s',
#  '131',
#  '1318',
#  '132',
#  '134',
#  '135',
#  '135m',
#  '136',
#  '137',
#  '138',
#  '139',
#  '13k',
#  '13s',
#  '13th',
#  '14',
#  '140',
#  '1408',
#  '140hp',
#  '1415',
#  '142',
#  '145',
#  '1454',
#  '146',
#  '147',
#  '1473',
#  '149',
#  '1492',
#  '14a',
#  '14ieme',
#  '14s',
#  '14th',
#  '14yr',
#  '14ème',
#  '15',
#  '150',
#  '1500',
#  '1500s',
#  '150_worst_cases_of_nepotism',
#  '150k',
#  '150m',
#  '151',
#  '152',
#  '153',
#  '1547',
#  '155',
#  '156',
#  '1561',
#  '157',
#  '158',
#  '1594',
#  '15mins',
#  '15minutes',
#  '15s',
#  '15th',
#  '16',
#  '160',
#  '1600',
#  '1600s',
#  '160lbs',
#  '161',
#  '1610',
#  '163',
#  '164',
#  '165',
#  '166',
#  '1660s',
#  '168',
#  '169',
#  '1692',
#  '16ieme',
#  '16k',
#  '16mm',
#  '16s',
#  '16th',
#  '16x9',
#  '16ème',
#  '16éme',
#  '17',
#  '170',
#  '1700',
#  '1700s',
#  '1701',
#  '171',
#  '175',
#  '177',
#  '1775',
#  '1780s',
#  '1790s',
#  '1794',
#  '1798',
#  '17million',
#  '17th',
#  '18',
#  '180',
#  '1800',
#  '1800mph',
#  '1800s',
#  '1801',
#  '1805',
#  '1809',
#  '180d',
#  '1812',
#  '1813',
#  '18137',
#  '1814',
#  '1816',
#  '1820',
#  '1824',
#  '183',
#  '1830',
#  '1832',
#  '1836',
#  '1837',
#  '1838',
#  '1839',
#  '1840',
#  '1840s',
#  '1844',
#  '1846',
#  '1847',
#  '185',
#  '1850',
#  '1850ies',
#  '1850s',
#  '1852',
#  '1853',
#  '1854',
#  '1855',
#  '1859',
#  '1860',
#  '1860s',
#  '1861',
#  '1862',
#  '1863',
#  '1864',
#  '1865',
#  '1870',
#  '1870s',
#  '1871',
#  '1873',
#  '1874',
#  '1875',
#  '1876',
#  '188',
#  '1880',
#  '1880s',
#  '1881',
#  '1886',
#  '1887',
#  '1888',
#  '1889',
#  '188o',
#  '1890',
#  '1890s',
#  '1892',
#  '1893',
#  '1894',
#  '1895',
#  '1896',
#  '1897',
#  '1898',
#  '1899',
#  '18a',
#  '18s',
#  '18th',
#  '18year',
#  '19',
#  '190',
#  '1900',
#  '1900s',
#  '1901',
#  '1902',
#  '1903',
#  '1904',
#  '1905',
#  '1906',
#  '1907',
#  '1908',
#  '1909',
#  '1910',
#  '1910s',
#  '1911',
#  '1912',
#  '1913',
#  '1914',
#  '1915',
#  '1916',
#  '1917',
#  '1918',
#  '1919',
#  '192',
#  '1920',
#  '1920ies',
#  '1920s',
#  '1921',
#  '1922',
#  '1923',
#  '1924',
#  '1925',
#  '1926',
#  '1927',
#  '1928',
#  '1929',
#  '1930',
#  '1930ies',
#  '1930s',
#  '1931',
#  '1932',
#  '1933',
#  '1934',
#  '1935',
#  '1936',
#  '1937',
#  '1938',
#  '1939',
#  '193o',
#  '194',
#  '1940',
#  '1940s',
#  '1941',
#  '1942',
#  '1943',
#  '1944',
#  '1945',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '1949er',
#  '195',
#  '1950',
#  '1950s',
#  '1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '1960',
#  '1960s',
#  '1961',
#  '1961s',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '197',
#  '1970',
#  '1970ies',
#  '1970s',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '19796',
#  '197o',
#  '1980',
#  '1980ies',
#  '1980s',
#  '1981',
#  '1982',
#  '1982s',
#  '1983',
#  '1983s',
#  '1984',
#  '1984ish',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1990s',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '19k',
#  '19th',
#  '19thc',
#  '1am',
#  '1and',
#  '1d',
#  '1h',
#  '1h30',
#  '1h40',
#  '1h40m',
#  '1h53',
#  '1hour',
#  '1hr',
#  '1million',
#  '1min',
#  '1mln',
#  '1o',
#  '1s',
#  '1st',
#  '1ton',
#  '1tv',
#  '1½',
#  '1ç',
#  '20',
#  '200',
#  '2000',
#  '20000',
#  '20001',
#  '2000ad',
#  '2000s',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2004s',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '200ft',
#  '200th',
#  '201',
#  '2010',
#  '2012',
#  '2013',
#  '2015',
#  '2017',
#  '2019',
#  '2020',
#  '2022',
#  '2023',
#  '2030',
#  '2031',
#  '2033',
#  '2035',
#  '2036',
#  '2038',
#  '204',
#  '2040',
#  '2044',
#  '2046',
#  '2047',
#  '2050',
#  '2053',
#  '2054',
#  '206',
#  '2060',
#  '2070',
#  '2080',
#  '209',
#  '2090',
#  '20c',
#  '20ft',
#  '20k',
#  '20m',
#  '20mins',
#  '20minutes',
#  '20mn',
#  '20p',
#  '20perr',
#  '20s',
#  '20th',
#  '20ties',
#  '20widow',
#  '20x',
#  '20year',
#  '20yrs',
#  '21',
#  '210',
#  '2100',
#  '214',
#  '215',
#  '2151',
#  '216',
#  '21699',
#  '21849889',
#  '21849890',
#  '21849907',
#  '21st',
#  '22',
#  '220',
#  '2200',
#  '221',
#  '2210',
#  '22101',
#  '222',
#  '223',
#  '225',
#  '2257',
#  '225mins',
#  '227',
#  '22d',
#  '22h45',
#  '22nd',
#  '23',
#  '230lbs',
#  '230mph',
#  '231',
#  '232',
#  '233',
#  '236',
#  '237',
#  '23d',
#  '23rd',
#  '24',
#  '240',
#  '2400',
#  '241',
#  '242',
#  '248',
#  '2480',
#  '249',
#  '24m30s',
#  '24th',
#  '24years',
#  '25',
#  '250',
#  '2500',
#  '250000',
#  '25million',
#  '25mins',
#  '25s',
#  '25th',
#  '25yo',
#  '25yrs',
#  '26',
#  '260',
#  '2600',
#  '261k',
#  '262',
#  '2642',
#  '269',
#  '26th',
#  '27',
#  '270',
#  '272',
#  '273',
#  '274',
#  '275',
#  '2772',
#  '278',
#  '27th',
#  '27x41',
#  '28',
#  '280',
#  '285',
#  '28th',
#  '29',
#  '29th',
#  '2am',
#  '2d',
#  '2fast',
#  '2furious',
#  '2h',
#  '2h30',
#  '2hour',
#  '2hours',
#  '2hr',
#  '2hrs',
#  '2in',
#  '2inch',
#  '2k',
#  '2more',
#  '2nd',
#  '2oo4',
#  '2oo5',
#  '2pac',
#  '2point4',
#  '2s',
#  '2x4',
#  '30',
#  '300',
#  '3000',
#  '300ad',
#  '300c',
#  '300lbs',
#  '300mln',
#  '3012',
#  '303',
#  '305',
#  '30am',
#  '30ish',
#  '30k',
#  '30lbs',
#  '30min',
#  '30mins',
#  '30pm',
#  '30s',
#  '30something',
#  '30th',
#  '30ties',
#  '31',
#  '3199',
#  '31st',
#  '32',
#  '3200',
#  '320x180',
#  '32lb',
#  '32nd',
#  '33',
#  '330am',
#  '330mins',
#  '332960073452',
#  '336th',
#  '33m',
#  '34',
#  '345',
#  '3462',
#  '34th',
#  '35',
#  '350',
#  '3500',
#  '3516',
#  '356',
#  '357',
#  '35c',
#  '35mins',
#  '35mm',
#  '35pm',
#  '35th',
#  '35yr',
#  '36',
#  '360',
#  '365',
#  '36th',
#  '37',
#  '370',
#  '372',
#  '378',
#  '38',
#  '38k',
#  '38th',
#  '39',
#  '395',
#  '39th',
#  '3am',
#  '3bs',
#  '3d',
#  '3dvd',
#  '3k',
#  '3lbs',
#  '3m',
#  '3mins',
#  '3p',
#  '3p0',
#  '3pm',
#  '3po',
#  '3rd',
#  '3rds',
#  '3th',
#  '3who',
#  '3x5',
#  '3yrs',
#  '40',
#  '400',
#  '4000',
#  '401k',
#  '405',
#  '409',
#  '40am',
#  '40min',
#  '40mins',
#  '40mph',
#  '40s',
#  '40th',
#  '41',
#  '42',
#  '420',
#  '425',
#  '428',
#  '42nd',
#  '43',
#  '430',
#  '44',
#  '440',
#  '442nd',
#  '44c',
#  '44yrs',
#  '45',
#  '450',
#  '4500',
#  '451',
#  '454',
#  '45am',
#  '45min',
#  '45mins',
#  '45s',
#  '46',
#  '465',
#  '469',
#  '47',
#  '475',
#  '477',
#  '47s',
#  '48',
#  '480m',
#  '480p',
#  '48hrs',
#  '49',
#  '498',
#  '49th',
#  '4am',
#  '4cylinder',
#  '4d',
#  '4eva',
#  '4ever',
#  '4f',
#  '4h',
#  '4hrs',
#  '4k',
#  '4kids',
#  '4m',
#  '4o',
#  '4pm',
#  '4th',
#  '4w',
#  '4ward',
#  '4x',
#  '4x4',
#  '50',
#  '500',
#  '5000',
#  '500000',
#  '500ad',
#  '500db',
#  '500lbs',
#  '502',
#  '50c',
#  '50ft',
#  '50ies',
#  '50ish',
#  '50k',
#  '50min',
#  '50mins',
#  '50s',
#  '50th',
#  '50usd',
#  '51',
#  '51b',
#  '51st',
#  '52',
#  '5200',
#  '5250',
#  '529',
#  '52s',
#  '53',
#  '53m',
#  '54',
#  '5400',
#  '540i',
#  '54th',
#  '55',
#  '5539',
#  '555',
#  '55th',
#  '56',
#  '57',
#  '571',
#  '576',
#  '578',
#  '57d',
#  '58',
#  '58th',
#  '59',
#  '598947',
#  '59th',
#  '5hrs',
#  '5ive',
#  '5kph',
#  '5million',
#  '5min',
#  '5mins',
#  '5s',
#  '5seconds',
#  '5th',
#  '5x',
#  '5x5',
#  '5years',
#  '5yo',
#  '5yrs',
#  '60',
#  '600',
#  '6000',
#  '607',
#  '608',
#  '60ies',
#  '60ish',
#  '60mph',
#  '60s',
#  '60th',
#  '60ties',
#  '61',
#  '618',
#  '62',
#  '6200',
#  '62229249',
#  '63',
#  '637',
#  '63rd',
#  '64',
#  '65',
#  '65m',
#  '66',
#  '660',
#  '666',
#  '66er',
#  '67',
#  '6723',
#  '67th',
#  '68',
#  '68th',
#  '69',
#  '69th',
#  '6am',
#  '6b',
#  '6ft',
#  '6hours',
#  '6k',
#  '6million',
#  '6pm',
#  '6th',
#  '6wks',
#  '6yo',
#  '70',
#  '700',
#  '701',
#  '707',
#  '70ies',
#  '70m',
#  '70mm',
#  '70s',
#  '70th',
#  '71',
#  '713',
#  '72',
#  '72nd',
#  '73',
#  '7300',
#  '735',
#  '737',
#  '74',
#  '740',
#  '740il',
#  '747',
#  '747s',
#  '74th',
#  '75',
#  '750',
#  '75054',
#  '75c',
#  '75m',
#  '76',
#  '7600',
#  '77',
#  '78',
#  '788',
#  '78rpm',
#  '79',
#  '79th',
#  '7days',
#  '7even',
#  '7eventy',
#  '7ft',
#  '7ish',
#  '7mm',
#  '7th',
#  '7½th',
#  '80',
#  '800',
#  '8000',
#  '80ies',
#  '80ish',
#  '80min',
#  '80s',
#  '80yr',
#  '81',
#  '817',
#  '819',
#  '82',
#  '820',
#  '8217',
#  '8230',
#  '83',
#  '84',
#  '849',
#  '84f',
#  '84s',
#  '85',
#  '850',
#  '850pm',
#  '86',
#  '86s',
#  '87',
#  '8700',
#  '8763',
#  '878',
#  '87minutes',
#  '88',
#  '88min',
#  '89',
#  '89or',
#  '89s',
#  '8bit',
#  '8ftdf',
#  '8k',
#  '8mm',
#  '8o',
#  '8p',
#  '8pm',
#  '8star',
#  '8th',
#  '8u',
#  '8½',
#  '90',
#  '900',
#  '9000',
#  '90210',
#  '905',
#  '90c',
#  '90ish',
#  '90min',
#  '90mins',
#  '90s',
#  '91',
#  '911',
#  '914',
#  '917',
#  '92',
#  '921',
#  '92fs',
#  '92nd',
#  '93',
#  '937',
#  '94',
#  '9484',
#  '94s',
#  '94th',
#  '95',
#  '950',
#  '95th',
#  '96',
#  '97',
#  '970',
#  '974th',
#  '978',
#  '98',
#  '987',
#  '98minutes',
#  '99',
#  '998',
#  '999',
#  '9999',
#  '99cents',
#  '99p',
#  '99½',
#  '9_',
#  '9am',
#  '9as',
#  '9do',
#  '9ers',
#  '9is',
#  '9lbs',
#  '9mm',
#  ...]

# %% [markdown]
# Попробуем кого-нибудь таки сконвертировать

# %%
vectorizer.transform([train_df['review'].iloc[3]])
# Out:
# <1x74849 sparse matrix of type '<class 'numpy.int64'>'
# 	with 206 stored elements in Compressed Sparse Row format>

# %% [markdown]
# То, что и хотели - вектор с bow (т.е. bag-of-words) представлением исходного текста.
#
# И чем эта информация может помочь? Ну, всё тем же - какие-то слова носят положительный окрас, какие-то - отрицательный. Большинство вообще нейтральный, да.
#
# ![bow with weights](https://github.com/DanAnastasyev/DeepNLP-Course/raw/master/Week%2001/Images/BOW_weights.png)
#
# Хочется, наверное, подобрать коэффициенты, которые будут определять уровень окраса, да? Подбирать нужно по обучающей выборке, а не как мы перед этим делали.
#
# Например, для выборки
# ```
# 1   The movie was excellent
# 0   the movie was awful
# ```
# легко подобрать коэффициенты на глазок: что-нибудь вроде `+1` для `excellent`,  `-1` для `awful` и по нулям всем остальным.
#
# Построим линейную модель, которая станет этим заниматься. Она будет учиться строить разделяющую гиперплоскость в пространстве bow-векторов.
#
# Проверим, как справится логистическая регрессия с нашей супер-выборкой из пары предложений

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

dummy_data = ['The movie was excellent',
              'the movie was awful']
dummy_labels = [1, 0]

vectorizer = CountVectorizer()
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(dummy_data, dummy_labels)

print(vectorizer.get_feature_names())
print(classifier.coef_)
# Out:
# ['awful', 'excellent', 'movie', 'the', 'was']
# [[-0.40104279  0.40104279  0.          0.          0.        ]]

# %% [markdown]
# Получилось что надо.
#
# Запустим теперь её на реальных данных.

# %%
model.fit(train_df['review'], train_df['is_positive'])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Pipeline(memory=None,
#          steps=[('vectorizer',
#                  CountVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('classifier',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
#                                     multi_class='auto', n_jobs=None,
#                                     penalty='l2', random_state=None,
#                                     solver='lbfgs', tol=0.0001, verbose=0,
#                                     warm_start=False))],
#          verbose=False)

# %%
from sklearn.metrics import accuracy_score

def eval_model(model, test_df):
    preds = model.predict(test_df['review'])
    print('Test accuracy = {:.2%}'.format(accuracy_score(test_df['is_positive'], preds)))
    
eval_model(model, test_df)
# Out:
# Test accuracy = 86.50%

# %% [markdown]
# Прогресс!
#
# Хочется как-то посмотреть, что заинтересовало классификатор. К счастью, сделать это совсем просто:

# %%
import eli5
eli5.show_weights(classifier, vec=vectorizer, top=40)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.855
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         refreshing
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.97%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.760
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         wonderfully
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.689
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         funniest
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.647
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         surprisingly
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.626
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         rare
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.432
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         superb
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.401
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         excellent
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.42%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.365
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         incredible
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.51%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.351
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         perfect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.302
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         delightful
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.264
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         vengeance
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 88.08%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 37681 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.97%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 37129 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 87.97%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.280
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         dull
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.97%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.281
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         worse
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.295
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         mildly
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.303
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         redeeming
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.349
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         baldwin
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.355
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         wooden
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.357
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         weak
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.379
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         badly
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.393
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         horrible
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.17%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -

# %% [markdown]
# Посмотрим на конкретные примеры его работы:

# %%
print('Positive' if test_df['is_positive'].iloc[1] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[1], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Positive
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>1.000</b>, score <b>18.921</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +18.937
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.86%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.016
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 95.29%); opacity: 0.81" title="-0.055">this</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.33%); opacity: 0.81" title="0.071">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.44%); opacity: 0.86" title="0.329">both</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.51%); opacity: 0.81" title="-0.068">an</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 71.13%); opacity: 0.93" title="0.728">entertaining</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.69%); opacity: 0.82" title="0.102">and</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="1.161">touching</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.68%); opacity: 0.81" title="-0.033">version</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.25%); opacity: 0.81" title="-0.073">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.85%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 79.12%); opacity: 0.88" title="0.458">classic</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.78%); opacity: 0.82" title="0.143">tale</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 86.26%); opacity: 0.84" title="0.252">also</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.29%); opacity: 0.83" title="0.177">quite</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 82.92%); opacity: 0.86" title="0.344">intelligent</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(0, 100.00%, 87.65%); opacity: 0.84" title="-0.217">not</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.25%); opacity: 0.81" title="-0.073">of</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.85%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> &#x27;</span><span style="background-color: hsl(120, 100.00%, 95.80%); opacity: 0.81" title="0.046">me</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.37%); opacity: 0.82" title="0.089">tarzan</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 85.62%); opacity: 0.85" title="0.269">you</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.93%); opacity: 0.84" title="0.235">jane</span><span style="opacity: 0.80">&#x27; </span><span style="background-color: hsl(120, 100.00%, 91.98%); opacity: 0.82" title="0.117">school</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.49%); opacity: 0.80" title="-0.022">at</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.18%); opacity: 0.80" title="-0.026">all</span><span style="opacity: 0.80">.  </span><span style="background-color: hsl(120, 100.00%, 89.60%); opacity: 0.83" title="0.169">it</span><span style="opacity: 0.80">&#x27;s </span><span style="background-color: hsl(120, 100.00%, 96.85%); opacity: 0.81" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.63%); opacity: 0.85" title="0.296">famous</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.54%); opacity: 0.80" title="-0.002">story</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.25%); opacity: 0.81" title= ...

# %%
print('Positive' if test_df['is_positive'].iloc[6] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[6], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Negative
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.000</b>, score <b>-10.913</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.016
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -10.897
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 95.90%); opacity: 0.81" title="-0.055">this</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.99%); opacity: 0.80" title="0.035">movie</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.07%); opacity: 0.81" title="0.071">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 66.37%); opacity: 0.96" title="-1.105">terrible</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 90.95%); opacity: 0.82" title="0.169">it</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.04%); opacity: 0.80" title="-0.034">was</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.56%); opacity: 0.81" title="0.061">so</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 91.95%); opacity: 0.82" title="-0.143">difficult</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.38%); opacity: 0.80" title="0.014">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.12%); opacity: 0.81" title="-0.092">believe</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.94%); opacity: 0.80" title="0.008">that</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 80.46%); opacity: 0.87" title="-0.509">katie</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 86.80%); opacity: 0.84" title="0.291">became</span><span style="opacity: 0.80"> a </span><span style="background-color: hsl(120, 100.00%, 81.07%); opacity: 0.87" title="0.486">heartfelt</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 93.45%); opacity: 0.82" title="0.107">teenager</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.63%); opacity: 0.80" title="0.011">with</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.26%); opacity: 0.80" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 85.51%); opacity: 0.85" title="-0.332">power</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.38%); opacity: 0.80" title="0.014">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-1.416">save</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.26%); opacity: 0.80" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 88.35%); opacity: 0.83" title="0.243">pity</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 87.57%); opacity: 0.84" title="0.267">chinese</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 94.82%); opacity: 0.81" title="0.076">people</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 97.26%); opacity: 0.80" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.99%); opacity: 0.80" title="0.035">movie</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 87.88%); opacity: 0.84" title="-0.257">didn</span><span style="opacity: 0.80">&#x27;t </span><span style="background-color: hsl(0, 100.00%, 96.02%); opacity: 0.81" title="-0.052">show</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.13%); opacity: 0.82" title="-0.139">any</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 87.70%); opacity: 0.84" title="-0.263">con ...

# %% [markdown]
# Посмотрим на примеры неправильной классификации, наконец:

# %%
import numpy as np

preds = model.predict(test_df['review'])
incorrect_pred_index = np.random.choice(np.where(preds != test_df['is_positive'])[0])

eli5.show_prediction(classifier, test_df['review'].iloc[incorrect_pred_index],
                     vec=vectorizer, targets=['positive'], target_names=['negative', 'positive'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.689</b>, score <b>0.795</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.812
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 98.69%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.016
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(120, 100.00%, 98.25%); opacity: 0.80" title="0.030">mount</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.74%); opacity: 0.80" title="0.002">godwin</span><span style="opacity: 0.80">-</span><span style="background-color: hsl(120, 100.00%, 88.37%); opacity: 0.83" title="0.454">austin</span><span style="opacity: 0.80"> (</span><span style="background-color: hsl(0, 100.00%, 85.44%); opacity: 0.85" title="-0.625">otherwise</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.47%); opacity: 0.82" title="0.291">known</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.52%); opacity: 0.80" title="0.050">as</span><span style="opacity: 0.80"> k2) </span><span style="background-color: hsl(120, 100.00%, 96.82%); opacity: 0.81" title="0.071">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.23%); opacity: 0.80" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 90.10%); opacity: 0.83" title="0.360">world</span><span style="opacity: 0.80">&#x27;s </span><span style="background-color: hsl(0, 100.00%, 97.09%); opacity: 0.80" title="-0.063">second</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.46%); opacity: 0.81" title="0.118">highest</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.03%); opacity: 0.80" title="0.064">mountain</span><span style="opacity: 0.80">, </span><span style="background-color: hsl(120, 100.00%, 95.90%); opacity: 0.81" title="0.102">and</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.28%); opacity: 0.81" title="-0.125">if</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.23%); opacity: 0.80" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.41%); opacity: 0.81" title="0.120">evidence</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 87.80%); opacity: 0.84" title="0.485">presented</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 99.34%); opacity: 0.80" title="0.008">in</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.36%); opacity: 0.80" title="-0.055">this</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.90%); opacity: 0.81" title="0.102">film</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.82%); opacity: 0.81" title="0.071">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.96%); opacity: 0.80" title="0.014">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.13%); opacity: 0.81" title="-0.094">be</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.90%); opacity: 0.81" title="-0.102">believed</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.82%); opacity: 0.81" title="0.071">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.23%); opacity: 0.80" title="0.031">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.62%); opacity: 0.81" title="0.113">hardest</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.03%); opacity: 0.80" title="0.064">mountain</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.96%); opacity: 0.80" title="0.014">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 89.17%); opacity: 0.83" title=" ...

# %% [markdown]
# ## Придумываем новые признаки

# %% [markdown]
# ### Tf-idf
#
# Сейчас мы на все слова смотрим с одинаковым весом - хотя какие-то из них более редкие, какие-то более частые, и эта частотность - полезная, вообще говоря, информация.
#
# Самый простой способ добавить статистическую информацию о частотностях - сделать *tf-idf* взвешивание:
#
# $$\text{tf-idf}(t, d) = \text{tf}(t, d) \times \text{idf}(t)$$
#
# *tf* - term-frequency - частотность слова `t` в конкретном документе `d` (рецензии в нашем случае). Это ровно то, что мы уже считали.
#
# *idf* - inverse document-frequency - коэффициент, который тем больше, чем в меньшем числе документов встречалось данное слово. Считается как-нибудь так:
# $$\text{idf}(t) = \text{log}\frac{1 + n_d}{1 + n_{d(t)}} + 1$$
# где $n_d$ - число всех документов, а $n_{d(t)}$ - число документов со словом `t`.
#
# Использовать его просто - нужно заменить `CountVectorizer` на `TfidfVectorizer`.
#
# **Задание** Попробуйте запустить `TfidfVectorizer`. Посмотрите на ошибки, которые он научился исправлять, и на ошибки, которые он начал делать - по сравнению с `CountVectorizer`.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 88.28%

# %% [markdown]
# ### N-граммы слов
#
# До сих пор мы смотрели на тексты как на мешок слов - но очевидно, что есть разница между `good movie` и `not good movie`.
#
# Добавим информацию (хоть какую-то) о последовательностях слов - будем извлекать еще и биграммы слов.
#
# В Vectorizer'ах для этого есть параметр `ngram_range=(n_1, n_2)` - он говорит, что нужны n_1-...n_2-граммы.
#
# **Задание** Попробуйте увеличенный range и поинтерпретируйте полученный результат.

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# Test accuracy = 88.64%

# %% [markdown]
# ### N-граммы символов
#
# Символьные n-граммы дают простой способ выучить полезные корни и суффиксы, не связываясь с этой вашей лингвистикой - только статистика, только хардкор.
#
# Например, слово `badass` мы можем представить в виде такой последовательности триграмм:
#
# `##b #ba bad ada das ass ss# s##`
#
# So interpretable, неправда ли?
#
# Реализовать это дело всё так же просто - нужно поставить `analyzer='char'` в вашем любимом Vectorizer'е и выбрать размер `ngram_range`.
#
# **Задание** Запилите классификатор на n-граммах символов и визуализируйте его.

# %%
vectorizer = TfidfVectorizer(ngram_range=(2, 6), max_features=20000, analyzer='char')
classifier = LogisticRegression()

model = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model.fit(train_df['review'], train_df['is_positive'])

eval_model(model, test_df)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Test accuracy = 87.86%

# %%
print('Positive' if test_df['is_positive'].iloc[1] else 'Negative')
eli5.show_prediction(classifier, test_df['review'].iloc[1], vec=vectorizer, 
                     targets=['positive'], target_names=['negative', 'positive'])
# Out:
# Positive
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.962</b>, score <b>3.245</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.195
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.050
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 94.93%); opacity: 0.81" title="-0.002">t</span><span style="background-color: hsl(120, 100.00%, 98.16%); opacity: 0.80" title="0.000">h</span><span style="background-color: hsl(120, 100.00%, 92.76%); opacity: 0.82" title="0.003">i</span><span style="background-color: hsl(120, 100.00%, 86.80%); opacity: 0.84" title="0.007">s</span><span style="background-color: hsl(120, 100.00%, 81.04%); opacity: 0.87" title="0.011"> </span><span style="background-color: hsl(120, 100.00%, 83.93%); opacity: 0.85" title="0.009">i</span><span style="background-color: hsl(120, 100.00%, 89.70%); opacity: 0.83" title="0.005">s</span><span style="background-color: hsl(120, 100.00%, 92.26%); opacity: 0.82" title="0.003"> </span><span style="background-color: hsl(120, 100.00%, 92.75%); opacity: 0.82" title="0.003">b</span><span style="background-color: hsl(120, 100.00%, 86.27%); opacity: 0.84" title="0.007">o</span><span style="background-color: hsl(120, 100.00%, 81.77%); opacity: 0.87" title="0.011">t</span><span style="background-color: hsl(120, 100.00%, 81.37%); opacity: 0.87" title="0.011">h</span><span style="background-color: hsl(120, 100.00%, 83.22%); opacity: 0.86" title="0.009"> </span><span style="background-color: hsl(120, 100.00%, 91.76%); opacity: 0.82" title="0.003">a</span><span style="background-color: hsl(120, 100.00%, 89.80%); opacity: 0.83" title="0.005">n</span><span style="background-color: hsl(120, 100.00%, 87.11%); opacity: 0.84" title="0.006"> </span><span style="background-color: hsl(120, 100.00%, 82.60%); opacity: 0.86" title="0.010">e</span><span style="background-color: hsl(120, 100.00%, 83.40%); opacity: 0.86" title="0.009">n</span><span style="background-color: hsl(120, 100.00%, 87.89%); opacity: 0.84" title="0.006">t</span><span style="background-color: hsl(120, 100.00%, 83.18%); opacity: 0.86" title="0.009">e</span><span style="background-color: hsl(120, 100.00%, 75.75%); opacity: 0.90" title="0.016">r</span><span style="background-color: hsl(120, 100.00%, 73.19%); opacity: 0.91" title="0.018">t</span><span style="background-color: hsl(120, 100.00%, 76.27%); opacity: 0.89" title="0.016">a</span><span style="background-color: hsl(120, 100.00%, 79.55%); opacity: 0.88" title="0.013">i</span><span style="background-color: hsl(120, 100.00%, 82.18%); opacity: 0.86" title="0.010">n</span><span style="background-color: hsl(120, 100.00%, 88.42%); opacity: 0.83" title="0.006">i</span><span style="background-color: hsl(120, 100.00%, 96.38%); opacity: 0.81" title="0.001">n</span><span style="background-color: hsl(120, 100.00%, 97.01%); opacity: 0.80" title="0.001">g</span><span style="background-color: hsl(120, 100.00%, 92.90%); opacity: 0.82" title="0.003"> </span><span style="background-color: hsl(120, 100.00%, 86.29%); opacity: 0.84" title="0.007">a</span><span style="background-color: hsl(120, 100.00%, 81.53%); opacity: 0.87" title="0.011">n</span><span style="background-color: hsl(120, 100.00%, 86.23%); opacity: 0.84" title="0.007">d</span><span style="background-color: hsl(120, 100.00%, 94.01%); opacity: 0.81" title="0.002"> </span><span style="background-color: hsl(120, 100.00%, 98.84%); opacity: 0.80" title="0.000">a</span><span style="background-color: hsl(120, 100.00%, 88.19%); opacity: 0.83" title="0.006"> </span><span style="background-color: hsl(120, 100.00%, 79.57%); opacity: 0.88" title="0.013">t</span><span style="background-color: hsl(120, 100.00%, 73.75%); opacity: 0.91" title="0.018">o</span><span style="background-color: hsl(120, 100.00%, 73.15%); opacity: 0.91" title="0.018">u</span><span style="background-color: hsl(120, 100.00%, 80.55%); opacity: 0.87" title="0.012">c</span><span style="background-color: hsl(120, 100.00%, 89.33%); opacity: 0.83" title="0.005">h</span><span style="background-color: hsl(0, 100.00%, 90.56%); opacity: 0.83" title="-0.004">i</span><span style="background-color: hsl(0, 100.00%, 87.40%); opacity: 0.84" title="-0.006">n</span><span ...

# %% [markdown]
# ## Подключаем лингвистику

# %% [markdown]
# ### Лемматизация и стемминг
#
# Если присмотреться, можно найти формы одного слова с разной семантической окраской по мнению классификатора. Или нет?
#
# **Задание** Найти формы слова с разной семантической окраской.
#
# Поверя, что они есть, попробуем что-нибудь с этим сделать.
#
# Например, лемматизируем - сведем к начальной форме все слова. Поможет в этом библиотека spacy.

# %%
import spacy
from spacy import displacy

nlp = spacy.load('en', disable=['parser'])

docs = [doc for doc in nlp.pipe(train_df.review.values[:50])]

# %%
train_df
# Out:
#        is_positive                                             review
# 0                0  Dreamgirls, despite its fistful of Tony wins i...
# 1                0  This show comes up with interesting locations ...
# 2                1  I simply love this movie. I also love the Ramo...
# 3                0  Spoilers ahead if you want to call them that.....
# 4                1  My all-time favorite movie! I have seen many m...
# ...            ...                                                ...
# 24995            1  I am a big fan of the movie, but not for the u...
# 24996            0  I'm not going to bother with a plot synopsis s...
# 24997            0  This movie . . . I don't know. Why they would ...
# 24998            1  Saw this film on DVD yesterday and was gob-sma...
# 24999            0  This was a disappointment - none of the nuance...
#
# [25000 rows x 2 columns]

# %%
for token in docs[0]:
    print(token.text, token.lemma_, token.ent_iob_, token.ent_type_)
# Out:
# Dreamgirls Dreamgirls B ORG
# , , O
# despite despite O
# its -PRON- O
# fistful fistful O
# of of O
# Tony Tony B PERSON
# wins win O
# in in O
# an an B DATE
# incredibly incredibly I DATE
# weak weak I DATE
# year year I DATE
# on on O
# Broadway Broadway B FAC
# , , O
# has have O
# never never O
# been be O
# what what O
# one one O
# would would O
# call call O
# a a O
# jewel jewel O
# in in O
# the the O
# crown crown O
# of of O
# stage stage O
# musicals musical O
# . . O
# However however O
# , , O
# that that O
# is be O
# not not O
# to to O
# say say O
# that that O
# in in O
# the the O
# right right O
# cinematic cinematic O
# hands hand O
# it -PRON- O
# could could O
# not not O
# be be O
# fleshed flesh O
# out out O
# and and O
# polished polish O
# into into O
# something something O
# worthwhile worthwhile O
# on on O
# - - O
# screen screen O
# . . O
# Unfortunately unfortunately O
# , , O
# what what O
# transfers transfer O
# to to O
# the the O
# screen screen O
# is be O
# basically basically O
# a a O
# slavishly slavishly O
# faithful faithful O
# version version O
# of of O
# the the O
# stage stage O
# hit hit O
# with with O
# all all O
# of of O
# its -PRON- O
# inherent inherent O
# weaknesses weakness O
# intact intact O
# . . O
# First first B ORDINAL
# , , O
# the the O
# score score O
# has have O
# never never O
# been be O
# one one O
# of of O
# the the O
# strong strong O
# points point O
# of of O
# this this O
# production production O
# and and O
# the the O
# film film O
# does do O
# not not O
# change change O
# that that O
# factor factor O
# . . O
# There there O
# are be O
# lots lot O
# of of O
# songs song O
# ( ( O
# perhaps perhaps O
# too too O
# many many O
# ? ? O
# ) ) O
# , , O
# but but O
# few few O
# of of O
# them -PRON- O
# are be O
# especially especially O
# memorable memorable O
# . . O
# The the O
# closest close O
# any any O
# come come O
# to to O
# catchy catchy O
# tunes tune O
# are be O
# the the O
# title title O
# song song O
# and and O
# One one B TIME
# Night Night I TIME
# Only only O
# - - O
# the the O
# much much O
# acclaimed acclaim O
# And and O
# I -PRON- O
# Am be O
# Telling tell O
# You -PRON- O
# That that O
# I -PRON- O
# Am be O
# Not not O
# Going go O
# is be O
# less less O
# a a O
# great great O
# song song O
# than than O
# it -PRON- O
# is be O
# a a O
# dramatic dramatic O
# set set O
# piece piece O
# for for O
# the the O
# character character O
# of of O
# Effie effie B PERSON
# ( ( O
# Jennifer Jennifer B PERSON
# Hudson Hudson I PERSON
# ) ) O
# . . O
# The the O
# film film O
# is be O
# slick slick O
# and and O
# technically technically O
# well well O
# - - O
# produced produce O
# , , O
# but but O
# the the O
# story story O
# and and O
# characters character O
# are be O
# surprisingly surprisingly O
# thin thin O
# and and O
# lacking lack O
# in in O
# any any O
# resonance resonance O
# . . O
# There there O
# is be O
# some some O
# interest interest O
# in in O
# the the O
# opening opening O
# moments moment O
# , , O
# watching watch O
# Jamie Jamie B PERSON
# Foxx Foxx I PERSON
# 's 's I PERSON
# Svengali Svengali O
# - - O
# like like O
# manager manager O
# manipulate manipulate O
# his -PRON- O
# acts act O
# to to O
# the the O
# top top O
# , , O
# but but O
# that that O
# takes take O
# a a O
# back back O
# seat seat O
# in in O
# the the O
# latter latter O
# portion portion O
# of of O
# the the O
# film film O
# , , O
# when when O
# the the O
# story story O
# conveniently conveniently O
# tries try O
# to to O
# cast cast O
# him -PRON- O
# as as O
# a a O
# villain villain O
# , , O
# despite despite O
# his -PRON- O
# having have O
# been be O
# right right O
# from from O
# a a O
# business business O
# stand stand O
# - - O
# point point O
# for for O
# a a O
# good good O
# majority majority O
# of of O
# the the O
# film film O
# . . O
# Beyonce Beyonce B PERSON
# Knowles Knowles I PERSON
# is be O
# lovely lovely O
# and and O
# sings sing O
# her -PRON- O
# songs song O
# perfectly perfectly O
# well well O
# , , O
# but but O
# is be O
# stuck stick O
# with with O
# a a O
# character character O
# who who O
# is be O
# basically basically O
# all all O
# surface surface O
# glitz glitz O
# . . O
# Anika Anika B PERSON
# Noni Noni I PERSON
# Rose Rose I PERSON
# as as O
# the the O
# third third B ORDINAL
# member member O
# of of O
# the the O
# Dreamgirls Dreamgirls B ORG
# trio trio O
# literally literally O
# has have O
# nothing nothing O
# to to O
# do do O
# for for O
# the the O
# entire entire O
# film film O
# . . O
# Eddie Eddie B PERSON
# Murphy Murphy I PERSON
# acquits acquit O
# himself -PRON- O
# well well O
# as as O
# a a O
# singer singer O
# obviously obviously O
# based base O
# on on O
# James James B PERSON
# Brown Brown I PERSON
# , , O
# but but O
# the the O
# role role O
# is be O
# not not O
# especially especially O
# meaty meaty O
# and and O
# ultimately ultimately O
# has have O
# little little O
# impact impact O
# . . O
# Foxx Foxx B PERSON
# would would O
# seem seem O
# ideal ideal O
# casting casting O
# , , O
# but but O
# he -PRON- O
# seems seem O
# oddly oddly O
# withdrawn withdraw O
# and and O
# bored bored O
# . . O
# The the O
# film film O
# 's 's O
# biggest big O
# selling selling O
# point point O
# is be O
# surely surely O
# former former O
# American American B ORG
# Idol Idol I ORG
# contestant contestant O
# / / O
# Oscar Oscar B PERSON
# winner winner O
# Jennifer Jennifer B PERSON
# Hudson Hudson I PERSON
# in in O
# the the O
# central central O
# role role O
# of of O
# Effie Effie B PERSON
# White White I PERSON
# , , O
# the the O
# temperamental temperamental O
# singer singer O
# who who O
# gets get O
# booted boot O
# from from O
# the the O
# group group O
# and and O
# makes make O
# a a O
# triumphant triumphant O
# closing closing O
# act act O
# return return O
# . . O
# For for O
# me -PRON- O
# , , O
# Effie Effie B PERSON
# has have O
# always always O
# been be O
# a a O
# big big O
# problem problem O
# in in O
# both both O
# the the O
# show show O
# and and O
# the the O
# movie movie O
# . . O
# The the O
# film film O
# obviously obviously O
# wants want O
# you -PRON- O
# to to O
# feel feel O
# sorry sorry O
# for for O
# her -PRON- O
# and and O
# rather rather O
# ham ham O
# - - O
# handedly handedly O
# takes take O
# her -PRON- O
# side side O
# , , O
# but but O
# I -PRON- O
# have have O
# never never O
# been be O
# sure sure O
# that that O
# this this O
# character character O
# deserves deserve O
# that that O
# kind kind O
# of of O
# devotion devotion O
# . . O
# From from O
# the the O
# start start O
# , , O
# Effie effie B PERSON
# conducts conduct O
# herself -PRON- O
# for for O
# the the O
# most most O
# part part O
# like like O
# an an O
# obnoxious obnoxious O
# , , O
# egotistical egotistical O
# , , O
# self self O
# - - O
# centered center O
# diva diva O
# , , O
# who who O
# is be O
# more more O
# interested interested O
# in in O
# what what O
# everyone everyone O
# else else O
# can can O
# do do O
# for for O
# her -PRON- O
# rather rather O
# than than O
# having have O
# much much O
# vested vest O
# interest interest O
# in in O
# the the O
# group group O
# of of O
# which which O
# she -PRON- O
# is be O
# a a O
# part part O
# . . O
# When when O
# she -PRON- O
# is be O
# booted boot O
# from from O
# the the O
# group group O
# for for O
# her -PRON- O
# unprofessionalism unprofessionalism O
# and and O
# bad bad O
# attitude attitude O
# , , O
# the the O
# charges charge O
# are be O
# more more O
# than than O
# well well O
# - - O
# founded found O
# , , O
# but but O
# the the O
# stage stage O
# show show O
# / / O
# film film O
# seem seem O
# to to O
# think think O
# Effie effie B PERSON
# should should O
# be be O
# cut cut O
# unlimited unlimited O
# slack slack O
# simply simply O
# because because O
# she -PRON- O
# has have O
# a a O
# great great O
# voice voice O
# . . O
# Even even O
# though though O
# the the O
# film film O
# tries try O
# to to O
# soften soften O
# some some O
# of of O
# Effie Effie B PERSON
# 's 's O
# harder hard O
# edges edge O
# to to O
# make make O
# her -PRON- O
# more more O
# likable likable O
# , , O
# the the O
# charges charge O
# still still O
# stand stand O
# . . O
# Her -PRON- O
# story story O
# becomes become O
# more more O
# manipulative manipulative O
# by by O
# suggesting suggest O
# she -PRON- O
# should should O
# have have O
# our -PRON- O
# further further O
# sympathy sympathy O
# because because O
# she -PRON- O
# is be O
# an an O
# unwed unwed O
# mother mother O
# struggling struggle O
# to to O
# raise raise O
# her -PRON- O
# daughter daughter O
# - - O
# using use O
# the the O
# implication implication O
# that that O
# ( ( O
# much much O
# like like O
# the the O
# talent talent O
# card card O
# ) ) O
# motherhood motherhood O
# immediately immediately O
# makes make O
# any any O
# behavior behavior O
# excusable excusable O
# . . O
# Indeed indeed O
# the the O
# only only O
# big big O
# effort effort O
# the the O
# film film O
# makes make O
# to to O
# show show O
# Effie Effie B PERSON
# 's 's O
# mothering mothering O
# is be O
# to to O
# tell tell O
# us -PRON- O
# about about O
# it -PRON- O
# and and O
# then then O
# include include O
# a a O
# scene scene O
# where where O
# she -PRON- O
# barks bark O
# at at O
# her -PRON- O
# daughter daughter O
# in in O
# the the O
# unemployment unemployment O
# office office O
# , , O
# insists insist O
# that that O
# the the O
# girl girl O
# has have O
# " " O
# no no O
# father father O
# " " O
# and and O
# then then O
# refuse refuse O
# to to O
# look look O
# for for O
# gainful gainful O
# employment employment O
# to to O
# support support O
# them -PRON- O
# since since O
# singing singing O
# is be O
# all all O
# she -PRON- O
# knows know O
# . . O
# In in O
# the the O
# hands hand O
# of of O
# a a O
# skillful skillful O
# actress actress O
# , , O
# the the O
# gaps gap O
# could could O
# perhaps perhaps O
# have have O
# been be O
# remedied remedie O
# with with O
# technique technique O
# and and O
# charisma charisma O
# . . O
# Unfortunately unfortunately O
# , , O
# Hudson Hudson B PERSON
# is be O
# not not O
# that that O
# actress actress O
# . . O
# She -PRON- O
# sings sing O
# well well O
# , , O
# but but O
# the the O
# dialog dialog O
# - - O
# driven drive O
# moments moment O
# do do O
# not not O
# come come O
# naturally naturally O
# to to O
# her -PRON- O
# nor nor O
# do do O
# high high O
# emotional emotional O
# moments moment O
# . . O
# Effie effie B PERSON
# 's 's O
# signature signature O
# moment moment O
# ( ( O
# the the O
# aforementioned aforementioned O
# And and O
# I -PRON- O
# Am be O
# Telling tell O
# You -PRON- O
# ... ... O
# number number O
# ) ) O
# is be O
# well well O
# - - O
# sung sing O
# by by O
# Hudson Hudson B PERSON
# , , O
# but but O
# emotionally emotionally O
# flat flat O
# in in O
# the the O
# acting act O
# department department O
# . . O
# Effie effie B PERSON
# is be O
# supposed suppose O
# to to O
# expressing express O
# her -PRON- O
# rage rage O
# and and O
# desperation desperation O
# at at O
# her -PRON- O
# predicament predicament O
# , , O
# but but O
# Hudson Hudson B PERSON
# comes come O
# off off O
# as as O
# a a O
# cabaret cabaret O
# performer performer O
# belting belt O
# out out O
# a a O
# hot hot O
# number number O
# . . O
# All all O
# in in O
# all all O
# , , O
# not not O
# quite quite O
# the the O
# emotional emotional O
# highlight highlight O
# one one O
# expects expect O
# . . O
# The the O
# latter latter O
# portion portion O
# of of O
# the the O
# film film O
# is be O
# basically basically O
# a a O
# predictable predictable O
# melange melange O
# of of O
# events event O
# that that O
# maneuver maneuver O
# Foxx Foxx B ORG
# into into O
# Hudson Hudson B ORG
# 's 's O
# earlier early O
# position position O
# and and O
# allow allow O
# her -PRON- O
# to to O
# strut strut O
# back back O
# in in O
# and and O
# lord lord O
# it -PRON- O
# over over O
# everyone everyone O
# . . O
# Foxx Foxx B ORG
# 's 's O
# criminal criminal O
# offenses offense O
# in in O
# the the O
# film film O
# are be O
# undoubtedly undoubtedly O
# par par O
# for for O
# the the O
# course course O
# of of O
# many many O
# struggling struggle O
# record record O
# producers producer O
# , , O
# but but O
# the the O
# film film O
# 's 's O
# seeming seem O
# implication implication O
# that that O
# he -PRON- O
# has have O
# it -PRON- O
# coming come O
# because because O
# he -PRON- O
# helped help O
# usher usher O
# in in O
# the the O
# disco disco O
# era era O
# is be O
# rather rather O
# ridiculous ridiculous O
# , , O
# not not O
# to to O
# mention mention O
# pretentious pretentious O
# and and O
# condescending condescending O
# , , O
# particularly particularly O
# coming come O
# from from O
# a a O
# film film O
# with with O
# all all O
# of of O
# the the O
# depth depth O
# of of O
# a a O
# puddle puddle O
# . . O
# The the O
# end end O
# result result O
# is be O
# a a O
# faithful faithful O
# rendition rendition O
# of of O
# the the O
# stage stage O
# hit hit O
# , , O
# drained drain O
# of of O
# emotion emotion O
# , , O
# energy energy O
# or or O
# anything anything O
# that that O
# can can O
# be be O
# described describe O
# as as O
# dynamic dynamic O
# . . O

# %%
train_df
# Out:
#        is_positive                                             review
# 0                0  Dreamgirls, despite its fistful of Tony wins i...
# 1                0  This show comes up with interesting locations ...
# 2                1  I simply love this movie. I also love the Ramo...
# 3                0  Spoilers ahead if you want to call them that.....
# 4                1  My all-time favorite movie! I have seen many m...
# ...            ...                                                ...
# 24995            1  I am a big fan of the movie, but not for the u...
# 24996            0  I'm not going to bother with a plot synopsis s...
# 24997            0  This movie . . . I don't know. Why they would ...
# 24998            1  Saw this film on DVD yesterday and was gob-sma...
# 24999            0  This was a disappointment - none of the nuance...
#
# [25000 rows x 2 columns]

# %%
review_lemma = [' '.join([token.lemma_ for token in doc]) for doc in nlp.pipe(train_df.review.values)]

# %%
train_df_lemma = train_df.copy()
train_df_lemma['review_lemma'] = review_lemma
train_df_lemma
# Out:
#        is_positive  ...                                       review_lemma
# 0                0  ...  Dreamgirls , despite -PRON- fistful of Tony wi...
# 1                0  ...  this show come up with interesting location as...
# 2                1  ...  -PRON- simply love this movie . -PRON- also lo...
# 3                0  ...  spoiler ahead if -PRON- want to call -PRON- th...
# 4                1  ...  -PRON- all - time favorite movie ! -PRON- have...
# ...            ...  ...                                                ...
# 24995            1  ...  -PRON- be a big fan of the movie , but not for...
# 24996            0  ...  -PRON- be not go to bother with a plot synopsi...
# 24997            0  ...  this movie . . . -PRON- do not know . why -PRO...
# 24998            1  ...  see this film on dvd yesterday and be gob - sm...
# 24999            0  ...  this be a disappointment - none of the nuance ...
#
# [25000 rows x 3 columns]

# %%
docs_lemma = [' '.join([token.lemma_ for token in doc]) for doc in docs]
docs_lemma
# Out:
# ['Dreamgirls , despite -PRON- fistful of Tony win in an incredibly weak year on Broadway , have never be what one would call a jewel in the crown of stage musical . however , that be not to say that in the right cinematic hand -PRON- could not be flesh out and polish into something worthwhile on - screen . unfortunately , what transfer to the screen be basically a slavishly faithful version of the stage hit with all of -PRON- inherent weakness intact . first , the score have never be one of the strong point of this production and the film do not change that factor . there be lot of song ( perhaps too many ? ) , but few of -PRON- be especially memorable . the close any come to catchy tune be the title song and one Night only - the much acclaim and -PRON- be tell -PRON- that -PRON- be not go be less a great song than -PRON- be a dramatic set piece for the character of effie ( Jennifer Hudson ) . the film be slick and technically well - produce , but the story and character be surprisingly thin and lack in any resonance . there be some interest in the opening moment , watch Jamie Foxx \'s Svengali - like manager manipulate -PRON- act to the top , but that take a back seat in the latter portion of the film , when the story conveniently try to cast -PRON- as a villain , despite -PRON- have be right from a business stand - point for a good majority of the film . Beyonce Knowles be lovely and sing -PRON- song perfectly well , but be stick with a character who be basically all surface glitz . Anika Noni Rose as the third member of the Dreamgirls trio literally have nothing to do for the entire film . Eddie Murphy acquit -PRON- well as a singer obviously base on James Brown , but the role be not especially meaty and ultimately have little impact . Foxx would seem ideal casting , but -PRON- seem oddly withdraw and bored . the film \'s big selling point be surely former American Idol contestant / Oscar winner Jennifer Hudson in the central role of Effie White , the temperamental singer who get boot from the group and make a triumphant closing act return . for -PRON- , Effie have always be a big problem in both the show and the movie . the film obviously want -PRON- to feel sorry for -PRON- and rather ham - handedly take -PRON- side , but -PRON- have never be sure that this character deserve that kind of devotion . from the start , effie conduct -PRON- for the most part like an obnoxious , egotistical , self - center diva , who be more interested in what everyone else can do for -PRON- rather than have much vest interest in the group of which -PRON- be a part . when -PRON- be boot from the group for -PRON- unprofessionalism and bad attitude , the charge be more than well - found , but the stage show / film seem to think effie should be cut unlimited slack simply because -PRON- have a great voice . even though the film try to soften some of Effie \'s hard edge to make -PRON- more likable , the charge still stand . -PRON- story become more manipulative by suggest -PRON- should have -PRON- further sympathy because -PRON- be an unwed mother struggle to raise -PRON- daughter - use the implication that ( much like the talent card ) motherhood immediately make any behavior excusable . indeed the only big effort the film make to show Effie \'s mothering be to tell -PRON- about -PRON- and then include a scene where -PRON- bark at -PRON- daughter in the unemployment office , insist that the girl have " no father " and then refuse to look for gainful employment to support -PRON- since singing be all -PRON- know . in the hand of a skillful actress , the gap could perhaps have be remedie with technique and charisma . unfortunately , Hudson be not that actress . -PRON- sing well , but the dialog - drive moment do not come naturally to -PRON- nor do high emotional moment . effie \'s signature moment ( the aforementioned and -PRON- be tell -PRON- ... number ) be well - sing by Hudson , but emotionally flat in the act department . effie be suppose to expr ...
#  "this show come up with interesting location as fast as the travel channel . -PRON- be bill as reality but in actuality -PRON- be pure prime time soap opera . -PRON- be try to use exotic locale as a facade to bring people into a phony contest & then proceed to hook viewer on the contestants soap opera style .   -PRON- also borrow from an early CBS game show pioneer- Beat the Clock- by invent situation for -PRON- contestant to try & overcome . then -PRON- reward the winner money . if -PRON- can spice -PRON- up with a little interaction between the character , even better . while the game format be in slow motion versus Beat the Clock- the real accomplishment of this series be to escape reality .    this show have element of several type of successful past program . reality television , hardly , but if -PRON- hook on the contestant , locale or contest , this be -PRON- cup of tea . if -PRON- not , this entire series be as -PRON- say , drivel drip with gravy . -PRON- be another show hide behind the reality label which be the trend -PRON- start in 2000 .   -PRON- be slick & well produce , so -PRON- may last a while yet . after all , so do re - run of Gilligan 's Island , Green Acres , the Beverly Hillbillies & the Brady Bunch . this just do not employ professional actor . the intelligence level be about the same .",
#  '-PRON- simply love this movie . -PRON- also love the Ramones , so -PRON- be sorta biased to begin with in the first place . there be not a lot of critical praise to give this film , either -PRON- like -PRON- or -PRON- do not . -PRON- think -PRON- be a great cult movie .',
#  'spoiler ahead if -PRON- want to call -PRON- that ...   -PRON- would almost recommend this film just so people can truly see a 1/10 . where to begin , -PRON- will start from the top ...   the STORY : do not believe the premise - the movie have nothing to do with abandon car , and people finially understand what the mysterious happening be . -PRON- be a draub , basic , go to cabin movie with no intensity or " effort " .   the SCREENPLAY : -PRON- usually give credit to indie screenwriter , -PRON- be hard work when -PRON- be start out ... but this be crap . the story be flat - -PRON- leave -PRON- emotionless the entire movie . the dialogue be extremely weak and predictable boasting line of " Woah , -PRON- totally freak -PRON- out " and " -PRON- be wonder if -PRON- would uh ... if -PRON- would like to .. uh , would -PRON- come to the cabin with -PRON- ? " . -PRON- make -PRON- want to rip out all -PRON- hair , one strand at a time and feed -PRON- to -PRON- .   the character : HOLY crap ! ! ! ! some have describe the character as flat , -PRON- want to take -PRON- one step further and say that -PRON- actually have a reverse character arch .. -PRON- actually start work on a parallel universe and almost start act backwards ...   the actor : bad than the character be the actor . -PRON- take already poor write character and add in terrible high school drama act . the " Woah -PRON- totally freak -PRON- out " be say so monotone and slow - like -PRON- be dumbe down . -PRON- could complain for hour on the actor alone .   technical : LIGHTING : an eight year old would be disappoint with lighting on this movie . too shadowy in area , too bleach in other . the director should not use light as an emotion until -PRON- learn how to light a basic scene properly . Baby Steps ! sound : how many sound guy do -PRON- take to make a really shotty sound movie ? 9 . with that many sound guy this should sound amazing but quite the opposite have occur . there be one scene in particular that really stick out , these guy be drive in a car and the sound of the car change with every camera angle .... WEAK ! CAMERA : learn to use -PRON- .   anyway , -PRON- be run out of complain space ..... rent -PRON- - -PRON- dare -PRON- ... rent -PRON- and learn from -PRON- ... give -PRON- a 1 rating .. -PRON- deserve -PRON- .   sign off ... Amanda Christmas',
#  '-PRON- all - time favorite movie ! -PRON- have see many movie , but this one beat -PRON- all ! excelent acting , wonderful story . -PRON- will , as a " normal " care person start to love George . altough -PRON- be an actor , -PRON- be also -PRON- and a very lovable person . and maby most important thing : -PRON- will learn to respect & look different to people with Down Syndrome .',
#  "wonderful film , one of the good horror film of the 70 . -PRON- be realistic setting and atmosphere . as usual -PRON- be inevitable the usual negative comment . -PRON- have notice that most horror film of a certain period many time fail to reach even sufficiency . obviously because most horror movie be old and must be denigrati , be like a mental mechanism that move the mind of the potential of music critic here .   before -PRON- read the review already know what be the final judgment . in the film a good gift because 10 be really well do . Raines read quite well and the film as a way in which -PRON- be produce remind -PRON- a lot of Kubrick film . -PRON- really impression . excellent film really . -PRON- consider a film anthology of years'70 .",
#  "and shoot in Vancouver with the ' mountain ' of the low country of South Carolina visible in the background . for heaven 's sake , -PRON- should have reset the location . there be no coastal mountain in South Carolina . period .   lame visual . -PRON- should have be beautiful . and the story limp along .   -PRON- really do not understand why -PRON- be such a hit as a book , although -PRON- have to admit -PRON- be one -PRON- have not read as yet . usually -PRON- read the book and give the film a miss . there be nothing in this movie that make -PRON- want to buy the book , or even borrow -PRON- from the library .   verdict : the Mermaid Chair seem pretty shallow to moi .",
#  "this be the good dub -PRON- have ever hear by Disney , as well as the good adaptation since the big abuse ever on soundtrack , theme , character , dialogue in Kiki Delivery Service . Urrrghhh   this one have different atmosphere , especially the deviation from the common heroine . this one have both hero and heroine ( although -PRON- do not really endorse the use of hero & heroine here , since Miyazaki be out from the stereotype & common theme ) . as usual , after be introduce by Spirited away , amazed by Mononoke , trouble by Grave of Fireflies , and deeply touch by Majo no Takkyuubin , this one start with a bit doubt in -PRON- part . wonder if this will be the first Ghibi 's dud . well , in the end just like only Yesterday and Whisper of the Heart , -PRON- end up give 10 rating . -PRON- would give 9.8 rating , but the additional 0.2 be there to share the good feeling by encourage people to see the movie .   SPOILER somehow -PRON- see this as a sad movie , people die in this one , the lonely robot , the abandon place , and -PRON- end with destruction . -PRON- be as if mankind really can not live with too much power . the collapse scene give -PRON- patch of Metropolis end . -PRON- be just sad somehow . the plot be apparent in most review and the soundtrack rule as well ( as always ) . Joe Hisaishi really belong to Uematsu , Kanno , Williams caliber . People who can bring a movie , a game , an event to life , even to be a linger moment by astounding composition .   this be a feel good movie that use to be part of US cinema in the classic day ( -PRON- be a wonderful Life etc etc ) . well , thing change ....",
#  'link story : another first - time view for -PRON- and , again , this be one of the most popular of the Amicus anthology - and -PRON- be easy to see why , though -PRON- realize how the film \'s rather meaningless title could be mislead for some ; -PRON- certainly fancy director Peter Duffell \'s choice - death and the maiden ( which , incidentally , be a classical piece by Schubert that be hear in the film during the Peter Cushing episode ) - a great deal more . though the link device -PRON- be not all that great , the episode be all equally compelling and enjoyable . production value come off as very respectable indeed for the budget Duffell have to work with . the latter infuse the film with a great deal of style which be not so common with this type of film and , frankly , -PRON- make one regret the fact that -PRON- wish to distance -PRON- from the genre ( though more so as not to be typecast rather than because -PRON- feel -PRON- be beneath -PRON- ) .   now to the individual story -PRON- :    " Method for murder " : the opening segment do not offer any real surprise but , to make up for this , -PRON- be quietly suspenseful and appropriately creepy at time ( Tom Adams \' \' fictitious \' villain look like the long - lose brother of Boris Karloff from the old DARK HOUSE [ 1932 ] ) ; also , -PRON- end with a satisfactory DIABOLIQUE - type twist , and feature a fairly intense role for Denholm Elliott in the lead . that be all -PRON- need out of -PRON- , really .   " Waxworks " : for the second story -PRON- be introduce to a curiously romantic mood which be quite unusual for this type of film ; Peter Cushing and Joss Ackland be both excellent ( as well as impeccably dress ) in -PRON- role of two jilted lover of a woman who continue to obsess -PRON- even after such a long time , and whose friendly rivalry can only lead -PRON- blindly and inexorably to a fate that be literally bad than death ; an ominous hallucination scene with Peter Cushing be quite well do in view of the limited resource at hand , and Ackland \'s inexplicable inability - or unwillingness - to leave town somewhat recall the house - trap aristocrat of Bunuel \'s the exterminating ANGEL ( 1962 ) .   " sweet to the Sweet " : this be perhaps the fine episode of all - with -PRON- ambiguous role here , Christopher Lee continue to demonstrate -PRON- versatility and -PRON- be match by an understanding Nyree Dawn Porter and the deceptive innocence of Chloe Franks ( who appear as Lee \'s daughter ) . the film \'s treatment of the occult here be both subtle and mature , culminate in a powerful and extremely chilling \' curtain \' . trivia Note : Chloe Franks appear as a grown - up in the featurette include on the disc , and when -PRON- see -PRON- -PRON- feel an immediate familiarity with -PRON- face but could not quite put -PRON- finger on -PRON- . later , on read -PRON- filmography , -PRON- be reveal to -PRON- that -PRON- have play one of the lead in the long - run stage adaptation of Agatha Christie \'s " the Mousetrap " in London \'s West End , which -PRON- brother and -PRON- be fortunate enough to catch while -PRON- there on holiday in the Summer of 2002 ! needless to say , -PRON- have no idea then that -PRON- have once create such a delicate - and delicious - portrayal in sheer evil , mainly by virtue of -PRON- peculiar look and a devilish smile ! !    " The Cloak " : a wacky but oddly reverent vampire tale ( that still manage to debunk many of the myth attach to the subgenre , while invent some new one ! ) which take in some wonderful dig at exploitation cinema and , at one point , Christopher Lee -PRON- ! ; Jon Pertwee be marvelous as the campy horror star who get more than -PRON- bargain for when -PRON- attempt to bring a measure of authenticity to -PRON- work ; Ingrid Pitt send up -PRON- image nicely though -PRON- role be somewhat subsidiary to the proceeding ; Geoffrey Bayldon ( make up to look like Ernest Thesiger ) also have a memorably quirky bit ; the \' si ...
#  '" the Groove Tube " be one of only two Ken Shapiro movie , the other one be the equally zany " Modern Problems " . this one be just a full - scale parody of tv . aside from Shapiro - who apparently do not do anything after " Modern Problems " - the movie also star Chevy Chase and Henry Winkler \'s cousin Richard Belzer . the three cast member ( plus some other people in small role ) appear in various skit . one of the funny one feature Chase in a Geritol - spoof commercial , in which -PRON- be describe the medicine as -PRON- wife strip , and -PRON- end with -PRON- hump -PRON- . there be also a pornographic news program , an irritate cooking show , and the epic tale of some drug dealer .   anyway , the whole thing be just a real hoot . in -PRON- opinion , the three good tv - spoof movie be this one , plus " tunnelvision " and " Kentucky Fried Movie " ( although -PRON- may also include " the Truman Show " ) . really funny .   -PRON- wonder what ever do become of Ken Shapiro .',
#  'Jean Seberg have not one iota of act talent . like all -PRON- film , \' Bonjour tristesse \' suffer not at all from -PRON- look ( though -PRON- be perhaps the first of those modern woman whom Tom Wolfe gleefully , accurately describe as " boy with breast " : publicist , of course , use the word " gamine " ) but suffer grievously from Seberg \'s dull , monotonous , kill voice . in all -PRON- film when have to play anger , Seberg play -PRON- with grossly audible , distract , gasp pant between -PRON- monotonously drone verbalization . Oy .   Preminger \'s adaptation of Françoise Sagan \'s breathlessly juvenile , fantasy soap opera plot be noteworthy only for -PRON- lush cinematography - but then that be difficult to funk on the photogenic French Riviera , and perhaps for -PRON- apt , but certainly not groundbreake , employment of black & white for the present day scene from which Seberg \'s monotone narration deliver -PRON- to the flash - back - to color past .   Juliette Gréco have a brief moment , as a nightclub chanteuse in the black & white spotlight , deliver in smoky Dietrichesque voice the bleak existentialist lyric of the title song . this moment be nowadays , in retrospect , more than a wee bit drôle . except , of course , if -PRON- be French - particularly if -PRON- be a french " 68-er " longing for the glorious day of the barricade roundabout the Sorbonne - and -PRON- kid riot to retain the lifelong sinecure which have blight and emasculate France \'s economy : then -PRON- still believe in Sartre and Foucault and all such arcane , irrelevant theorist .   David Niven have the hard role , have to play with sufficient gusto an aging hedonist who be yet to grasp that life be not all about Sagan \'s teenybopper notion of a hip , cool , swingin \' , " mon copain ! " Papa . Deborah Kerr deliver -PRON- usual , consummately professional presence , convincingly play the woman who suffer undeservedly Seberg \'s spiteful teenaged snot - nose jealousy ( fulfil Sagan \'s shallow teen fantasy of the classical theme of " there can be only one Queen Bee in the hive " ) ; in fact , to Kerr belong this film \'s sole great and memorable on - screen moment .   the dialogue be unnatural - -PRON- agree with an early reviewer who say that -PRON- sound to be " badly translate " from French ; combine the unnatural scripting with Seberg \'s incomparably dull , unendurable monotone and -PRON- can save that Valium for another night . atop all that the ineptly synched post - production voice dub be , almost throughout , obvious and thus much more than irksome : this be especially true of the dubbing for Mylène Demongeot because -PRON- spoil -PRON- otherwise very pleasing dumb blonde performance .   Hunky Geoffrey Horne get the short end of the stick here - a very good look young man who also suffer from a less - than - lovely , uncinematic voice which , when pair with Seberg \'s drone , yield unconvince scene of puppy love . ( Horne be , shall -PRON- say , merely adequate in \' Bridge on the River Kwai , \' perhaps because -PRON- end be hold up by those great cinema pro William Holden and Jack Hawkins instead of be unsupported by the regrettably ungifted Seberg ) .   in sum \' Bonjour tristesse \' be pretty to look at but -PRON- be shallow , immature soap : thin gruel with sud .',
#  '-PRON- just come back from " El Otro " play here in Buenos Aires and -PRON- have to say -PRON- be very disappointed . the film be very slow move ( do not get -PRON- wrong , -PRON- enjoy slow move film ! ) , slow to the point of drive -PRON- crazy . all -PRON- hear be Julio Chavez breathe heavily throughout the whole film . this be a poorly make film , but more importantly , -PRON- be a film without a lick of inspiration , -PRON- feel nothing for the story or -PRON- character .   " El Otro " be make only for the sake of make a film ... make -PRON- forgetful . -PRON- would advise -PRON- to pass on this one , if -PRON- want to see good argentinian film , look for film by Sorin .',
#  'first of all let -PRON- start out by say that Robert Englund Doug Bradley and Melinda Clark should be commend for have to be associate with this piece of drivel . i have to give this a 1 -PRON- would not let -PRON- give -PRON- a zero . wanna know how bad this movie be ? -PRON- mom call -PRON- from across town and tell -PRON- " son , i just watch the stupid movie ever . i respond as say " the killer tongue huh ? " -PRON- be like how do -PRON- know that ? that be how bad this movie be . i mean -PRON- look like a good movie at first Freddy pinhead Melinda . okay -PRON- will give -PRON- a chance . i sit through the rest of this movie only because i write a column for review of horror movie . i implore -PRON- , do not waste -PRON- time money or even brain cell on this ludicrous piece of crap . run away . far away . if -PRON- see -PRON- on the shelf at Hollywood video blockbuster or even -PRON- local video store , turn -PRON- around and walk away .... and i still want -PRON- two hour back dang -PRON-',
#  'ever hear of a taiwanese horror movie ? or any taiwanese movie ? propably for a reason . this one be a really bore one , even though -PRON- have black magic include wither baby body and people explode from the inside with thousand of eel .   have read other people thought , -PRON- be look forward for some violence and gore , but there be not much at all . some blood puke and other lame stuff , if -PRON- be wait for graphic gore or any gruesome effect -PRON- will be disappoint . -PRON- clearly do not use the eel explode and other thing to -PRON- maximum potent .   pretty much nothing good about this movie ; a single character that be not completely bland and a few ok black magic spell , like the eel one . the plot be confusing and boring . the character be thin and annoying , include the main character . the horror aspect do not work at all , the most horrifying thing be an albino girl ( not that scary really ) . this be the bad asian horror movie -PRON- have ever see .',
#  'Melissa Joan Hart shine ! this show be amazing ! ! there be no match . except for maybe Melissa in Clarissa explain -PRON- all . -PRON- be marvelous in that , too . this be so much well than Buffy , the Vampire Slayer . this show be WONDERFUL !',
#  'the poor dvd video quality be the only reason why -PRON- give this movie a 9 instead of a 10 . that could have be so much well , this movie deserve -PRON- .   this be truly a movie that cover several theme simultaneously . if -PRON- do not like movie about serial killer , but be fascinate by the astonishing bureaucratic culture in the former Sovjet Union , this movie be a must - see anyway .   -PRON- can not compare -PRON- to " silence of the Lambs " for several reason . the way the serial killer be portray , have be do far much well in Citizen X. -PRON- see several detail of -PRON- private life , because -PRON- " travel " along with the killer , which give -PRON- some idea of the source of -PRON- constant anger and sexual frustration .   the only other movie -PRON- have see that be as realistic as this one be " Henry - portrait of a serial killer " . if -PRON- be fascinate by that movie -PRON- definitely need to take a look at Citizen X.',
#  '-PRON- find this on the shelf while housesitte and bored . how can people possibly give this a 10 ? -PRON- be not just that -PRON- be suppose to be a feel - good redemption film ( -PRON- think ) , because -PRON- do not work on that level either . weak plot , bad dialogue , terrible acting ; there be just nothing there . Harvey Keitel be decent , but have nothing to work with , and Bridget Fonda and especially Johnathon Schaech be just terrible . the plot progression ( especially the relationship between Byron and Ashley ) make no sense . -PRON- seem like the writer want the plot to go a certain way and make -PRON- , without actually write in the necessary bit to make -PRON- flow . -PRON- be only an hour and a half , but that be 90 minute of -PRON- life -PRON- will never get back .',
#  '-PRON- see this movie in the theater when -PRON- come out . -PRON- grow up in Scottsdale and -PRON- go to Arizona State and really enjoy see location where -PRON- spend so much time . -PRON- remember at the time think that Barbara \'s venture into more of a rock sound ( actually r and b - to -PRON- ear ) be a successful one . -PRON- be never a fan of Kris \'s singing until -PRON- last effort for New West . as a songwriter and an actor , though , -PRON- have serious chop , IMHO . -PRON- think -PRON- be a fine romance . -PRON- like -PRON- better than the Judy Garland version and never see Selznick \'s Janet Gaynor original .    -PRON- do believe that -PRON- make some change in this long - await dvd release . among other thing , -PRON- recall the helicopter shot which reveal a pack Sun Devil Stadium be long and more dramatic . -PRON- wish -PRON- have do a well job write music for Kris or God forbid , put some of -PRON- original song in there .    along those line -PRON- have some information from a primary source that say that the music be a problem for Kris and Barbara . while do interview for -PRON- own new music documentary , rock the Boat : a Musical Conversation and Journey , -PRON- interview Stephen Bruton , a fine singer / songwriter / guitarist with close professional and personal tie to Kris , Bonnie Raitt , and Delbert McClinton , among many other . Stephen be in " Speedway , " the John Norman character \'s band . Kris be have a real hard time turn what be essentially a pop score into something that could pass for rock . Stephen be and be Kris \'s friend and long time band member . there be tension on the set and at one point the band be bark at Kris in Barbara \'s presence . -PRON- remark to the effect that the band should not talk to -PRON- like that . Kris come right back to the effect that -PRON- be -PRON- friend and -PRON- be rock and roll ! in the end , Barbara come around and decide to use Kris \'s band \'s live performance in the movie and specifically site Stephen \'s role in make thing work . -PRON- gain even great respect for -PRON- as an artist upon hear this story . much be make of -PRON- as a diva . what -PRON- be be a pro . and -PRON- be not gay . not that there be anything wrong with that .',
#  'this be the bad ripoff of Home alone movie that -PRON- have EVER see ! watch part 1 and two , but do not let anyone say that this be well than the first two ! -PRON- mean , really , -PRON- do not make a movie , then make a sequel with the same character and actor , and then make another sequel with different character and actor ! -PRON- mean , -PRON- would have be ok if this wan\'t a " home alone " movie , but -PRON- do make -PRON- a Home alone movie . Culkin be too old now , so -PRON- be suppose to STOP make sequel ! goodness , this movie make -PRON- SICK ! buy part 1 and 2 .',
#  "the first scene in ' Problem Child ' have a baby pee into a nun 's face . for this movie , that be witty . a nasty , mean - spirited ' comedy ' , -PRON- be inept on so many level -PRON- beggar belief . John Ritter be the kind father who adopt the child from Hell , and kudo to -PRON- for maintain -PRON- dignity in the surround onslaught of one - note , annoying performance and puerile humour . and what the hell 's Jack Warden do in this mess ? slackly direct by Dennis Dugan and obnoxious in -PRON- attempt to turn on the sentimentality when -PRON- be do with the crudity , the movie be make so badly -PRON- be quite a bizarre experience . but never mind all that . the lowlight of the whole thing be Michael Oliver , the most repulsive and unlikeable kid actor ever to hit the screen \x96 believe -PRON- , -PRON- will want to smack -PRON- right in the mouth .",
#  'TOM BROWN \'s schooldays    aspect ratio : 1.78:1   sound format : stereo   in late 19th century England , young Tom Brown ( Alex Pettyfer ) be send to the public school at Rugby where -PRON- experience the reform of a radical new headmaster ( Stephen Fry ) and stand up to the school \'s resident bully , Flashman ( Joseph Beattie ) .   already the subject of numerous screen adaptation - most notably Gordon Parry \'s superior 1951 version - Thomas Hughes \' evergreen novel get the early 21st century treatment , courtesy of screenwriter Ashley Pharoah ( tv \'s " where the heart be " ) and director David Moore ( the FORSYTE SAGA ) . -PRON- be pleasant enough , and watchable , but -PRON- be also rather staid and dull , distinguish only by Fry \'s sincere performance as the new principal determine to sweep away some of the school \'s most dubious \' tradition \' , and by the introduction of a possible new star in 14 year old Pettyfer , a talented kid with the kind of effortless charm and vivid good look that should take -PRON- all the way to Hollywood and beyond . otherwise , this be typical UK tv fodder , the kind of stuff favor by executive eager to fill the schedule with \' prestige \' product , even one as thoroughly unremarkable as this . the UK publication \' Radio Times \' describe -PRON- as " daintily odd " and raise a querulous eyebrow over " all of that fagging and brutality and a handsome , rakish villain torture the life out of sweet young boy " . quite .',
#  'the Dereks do seem to struggle to find roll for Bo after " 10 " .   -PRON- use to work for a marine park in the Florida Keys . one day , the script for " Ghosts can not do -PRON- " be circulate among the trainer in the " fish house " where food be prepare for the dolphin . there be one scene where a -dolphin- supposedly proposition Bo ( or Bo the dolphin ) , ask to " go make egg . " read the script , -PRON- -lauuughed- ...   -PRON- do not end up do any portion of this movie at -PRON- facility , although -PRON- dolphin -were- in " the Big Blue ! "   this must have be very close to the end of Anthony Quinn \'s life . -PRON- hope -PRON- have fun in this film , as -PRON- certainly do not do anything for -PRON- legacy .',
#  'just like wine , " Johnny dangerously " get well and well with every day . this clever , witty , well - act film could very well stand on -PRON- own - but as a parody of the gangster genre , -PRON- be truly outstanding . in fact , -PRON- be quite obviously the good film of -PRON- kind ... the funniest spoof of mob movie and even the respective period - although , admittedly , this position be probably easy to achieve when -PRON- main competitor be such primitive , vulgar and dull pseudocomedie as " Jane Austen \'s Mafia " .',
#  "just see ICE AGE , a very funny and especially nice looking film . the story be simple but effective , the character lovable and nicely flesh out but what really shine be the digital set design .   More inspire by traditional animate movie than reality , the design give -PRON- a really , really nice looking world in a astounding use of colour . sometimes the touch of reality shine through ( especially the water be impressive ) , but nonetheless , -PRON- be a fantasy - world base on reality . include load of vast landscape especially help to minimise the cost of render .   Pixar film shine with technical brilliance , this one shine with effective use of technical know - how .   enough technical babble , the film 's entertaining , family - friendly and sometimes just hilariously funny .",
#  'though the title may suggest example of the 10 commandment , -PRON- be a definitely incorrect assumption . this be an adaptation of 9 SEEMINGLY unrelated story from Giovanni Bocaccio \'s 14th century " Decameron " story collection .   Set within a medieval italian town \'s largely peasant population , -PRON- be a diatribe on the reality of sex ( and -PRON- consequence ) within that world and time . a realistic view of life within this world , -PRON- sometimes feel like a journey back in time .   give the depict human element of -PRON- time , one can also see the more adventurous side of morality in -PRON- protagonist - as well as the irony of Life , at time . or -PRON- may also be view as a general satire of the Catholic Church \'s rule .   nothing terribly special , but definitely interesting if one come with no expectation or assumption .',
#  'Space Camp be a pretty decent film . the plot be predictable , but the actor do a good job , and the special effect be decent for the time .   this film be originally release about the time of the shuttle disaster , and that really put a hamper on how popular -PRON- be .   the scene where the shuttle door open in space be simply spectacular ... on the big screen , that is ... on a tv ... -PRON- just look average . -PRON- remember this scene in the theater . -PRON- make -PRON- feel like -PRON- be really up there .   this would be a good film to see on IMAX , but -PRON- be sure that will never happen .',
#  'this will be best know for the Ferrari that be crash when Eddie Griffin be do promotion .   tale of racing and betting be a poorly make by the number that appear to have a director who could not see the number . largely a point and shoot affair with a group of actor in -PRON- for a paycheck . this be not a good movie , but -PRON- not bad enough to be watchable and end up as a some what nothing film be not worth bother with no matter how -PRON- look at -PRON- .   Misogynistic , despite the fact one of the lead be a woman , this be a film that be clearly make just to get the producer and director close to pretty girl . want evidence ? there be long linger shot of woman in next to nothing that serve no purpose other than perhaps to get a rise out of people too afraid to rent a porno or the Sports illustrate swimsuit dvd .   avoid this movie at all cost',
#  '" Fever Pitch " be a sweet and charming addition to the small genre of sport romance as date movie or movie a son could be willing to go to with -PRON- mother ( though the guy in the audience get noticeably restless during the romantic scene ) .   -PRON- have live through a milder version of such a story , as -PRON- first exposure to baseball be date -PRON- husband the spring after the Mets first World Series win and then -PRON- watch the Mets clinch -PRON- next one because -PRON- be the one still up in the wee hour with -PRON- two little son , who have grow up to teach -PRON- more about baseball through -PRON- local neighborhood National League team \'s other heartbreaking failure to win -PRON- again ( and -PRON- be -PRON- who take -PRON- old son to -PRON- only Fenway Park game as -PRON- catch a bit of Red Sox fever as a graduate student in Boston ) .   so compare to reality , the script believably create two people with actual job . -PRON- be particularly impressive that Drew Barrymore \'s character be a substantive workaholic who have anti - barbie skill , though -PRON- pretty much only visit with -PRON- three bland girlfriend during gym workout that allow for much jiggling and the minor side story with -PRON- parent do not completely work .   -PRON- be even set up credibly how -PRON- meet Jimmy Fallon \'s math teacher and how -PRON- fall for -PRON- " winter guy " -- though -PRON- be surprising that -PRON- Red Sox paraphernalia fill apartment do not tip -PRON- off to -PRON- Jekyll - and - Hyde " summer guy . " -PRON- relationship crisis during the baseball season be also play out in a refreshingly grow - up way , from effort at compromise to -PRON- frank challenge to -PRON- , center around that -PRON- be both face thirty and single . fallon surprisingly rise to -PRON- character \'s gradual emotional maturity .   while the end borrow heavily from O. Henry , the script writer do a yeoman job of quickly incorporate the Sox \'s incredible 2004 season into a revised story line ( with lot of cooperation from the Red Sox organization for film at the stadium ) .   the script go out of -PRON- way to explain why Fallon do not have a Boston accent , as an immigrant from New Jersey , but that do not explain why -PRON- motley friend do not . the most authentic sound Boston sound come from most of -PRON- " summer family " of other season ticket holder , who kindly kibitz the basic of Sox lore to neophyte Barrymore ( and any such audience member ) .   the song selection include many Red Sox fan \' favorite , from the open note of the classic " Dirty Water , " though most be hold to be hear over the closing credit as if -PRON- be listen to local radio and be worth sit through to hear .',
#  'guy , -PRON- get to watch this awesome movie . at the end of this movie -PRON- will have a strong passion and profundity imbue into yourself . the acting of the two character , Billy Sunday and Carl Brashear deeply touch the heart from inside . this movie be about principle , dignity , patriotism and honor . -PRON- will hear Chief Carl Brashear say , the Navy have great tradition of all - honor - practice thoroughly by these two character . mere glance of these character during the movie fill -PRON- with enthusiasm . dialogue delivery of this movie be perfect . -PRON- can not find any flaw in the dialogue . what the Master Chief Billy say roam in and out of -PRON- mind for a long time after watch the movie . please watch this movie .',
#  "if -PRON- be amuse by straight - faced going - on that be logical within a give illogical situation , -PRON- will enjoy this whimsical 8-minute spanish film .   a woman enter a small café . the scene look ordinary , but the counterman , customer , and two musician seem somehow oddly subdue .   suddenly , the musician play and one man begin to sing the title song , dance across table top with musical - comedy gesture . the customer , at first immobile , at interval chime in ( badly but gamely ) with phrase from the song , read from slip of paper in -PRON- palm . on and off -PRON- jump up and dance ( awkwardly but earnestly ) in choreograph motion , like backup singer .   but why ? ? ? the woman wonder . the answer be reveal as the soloist 's jacket open and -PRON- see what be strap across -PRON- chest -- just before the explosive climax ...   even if -PRON- do not catch the song 's ( probably ironical ) lyric , the situation - perfect performance should give -PRON- a grin and a chuckle ... -PRON- would love to see -PRON- again !",
#  "whatever happen to Keaton be what -PRON- want to know .   actually -PRON- do not , -PRON- crawl away , heaving , think -PRON- must owe half the bookie in Vegas , or maybe not , maybe -PRON- be just brainwash , blackmail and bore to death . rich enough to adopt a third - world country , -PRON- somehow have to star in yet another cookie - cut , cliché - ride drool'athon , base on the same character - franchise -PRON- be be rehash since ' Father of the bride'('91 ) . -PRON- would think -PRON- be go head to head with Mr . Bean .   ( Spoilers )    so hubby ( Dax ) get 's fire by obnoxious son of boss , -PRON- mom ( Keaton)leaves -PRON- dad after classic row , and crash over with -PRON- own dog - show in tow , oh those little rascal . hubby 's get cold - foot for diaper - duty , wifey 's clock a - ticking and hey , let -PRON- toss in a space - cadet as second house - guest for good measure , all in one day because that be so funny and original . wife get feed up and walk away , mom leave dad for space - cadet and the couple make up in time for closing credit , 86 very long minute later .   now if -PRON- have to have a space - cadet , -PRON- can not be devious as well , -PRON- can not scheme some excuse for -PRON- stayover , and if mom leave dad , -PRON- can not hop into a cab dress as a pumpkin just because some scriptwriter agonize over how to cheer thing up .    plus that gag whereby -PRON- invite -PRON- in only to then discover -PRON- be get -PRON- canine entourage in the cab have get to be outlaw by now . and -PRON- only get one obnoxious 2-dimensional boss to denigrate . another movie - killer would be the movie - script the space cadet be toil away at , supposedly more lame than the actual one , again , dejas - ad - nausea .   Liv Tyler do not seem happy here , -PRON- voice be weird at time , -PRON- have -PRON- wonder if -PRON- later have -PRON- redub some of -PRON- , and -PRON- be a smart one , -PRON- be handle great role and -PRON- will forgive -PRON- for Jersey Girl , -PRON- be disaster - prone , could happen to anyone . Dax Shepard be watchable and that be be generous consider the material .   personally , -PRON- be the director , the screenwriter and especially the producer that -PRON- would love to see tar'n'feathered before ship to Guantanamo as plaything for the prisoner , and that be -PRON- keep this ' lite ' .",
#  'creative use of modern and mystical element : 1956 Cadillac convertible to transport evil stepmother Kathleen Turner ( John Waters \' " Serial Mom " ) and the 2 twist sister ; Queen Mab as the faerie godmother ; David Warner ( Evil in " Time Bandits " ) in redcoat at court ; Cinderella ( -PRON- be a babe ) shovel coal into an insatiable furnace ; Cinderella and -PRON- prince charm both look like ( and act like ) rock star . isle of Man location .',
#  'as a collector of movie memorabilia , -PRON- have to buy the movie poster for this film which , now that -PRON- have finally see -PRON- , have to be the good thing about -PRON- . there be nothing more attractive to hang on -PRON- wall than a 27x41 inch image of the melt man . however , there be nothing more awful to put in -PRON- vcr than an hour and a half long image of the melt man . at first -PRON- think this movie be pure garbage but then -PRON- realize that -PRON- do have some quality which make -PRON- laugh . the character of Dr. Ted Nelson have to be the most wishy - washy persona ever bring to the big screen . -PRON- dialogue be so trite -PRON- be unbelievable ! ( " -PRON- be incredible ! -PRON- seem to be get strong as -PRON- melt ! )   and could somebody tell -PRON- please how the heck -PRON- know exactly how much time Steve have leave before -PRON- melt completely and exactly what -PRON- plan be to " help " -PRON- ? if this movie be mean to scare -PRON- audience , -PRON- think -PRON- miss -PRON- calling .',
#  'Final Justice have the great Joe Don Baker run around Texas , shoot people who shoot people . then -PRON- be off to Malta where -PRON- shoot more people . -PRON- get lock up many time for shoot people . then -PRON- get into a gunfight with the bad guy , who be dress like a monk . there be a boat chase , and Joe Don wind up in jail again . finally Joe Don , with the help from Elaine from " Seinfeld " kill the bad guy , blow up a boat or two and someone get shoot with a flare . all this and a catchy theme song , just like Mitchell !',
#  '-PRON- must admit that -PRON- have be a sucker for Samurai flick since -PRON- can remember . -PRON- use to watch rather indiscriminate , be -PRON- " elitist " work like the Seven Samurai or the bloody comic - book variation like Lone Wolf and Cub . -PRON- also like US-/Japanese " crossover " like the Bushido Blade . and of course everything contain Sonny Chiba and Hiroyuki Sanada . and -PRON- have virtually watch every Samurai at least twice . but not Kabuto .   in 1993 -PRON- first watch Kabuto on video , that even Samurai film can be boring . in the beginning -PRON- be look forward to Mayeda reach Europe and the confrontation that would come from that but by the time -PRON- actually reach Spain , -PRON- really do not care so much for the movie anymore .   -PRON- would not do the film justice to call -PRON- " bad " . technically -PRON- be a clean entry into the genre . but there be simply never quiet enough . Sho Kosugi have limited skill as both director and actor and have only a fraction of above mention japanese actor charisma . and speak of Sho Kosugis son Kane , who appear in almost all Sho Kosugi film as Shos son : -PRON- have inherit little - to - none of -PRON- father limit act skill . add to the minus - point be the absence of the blood and gore that until then be a trademark of all Samurai film . this be obviously intend for a young us- / european audience .   Lets just say that -PRON- be a so - so film for the average historic - action - adventure fan but a bore for hardened fan of Samurai cinema . fan who be into the " samurai meet \x85 " -genre , should rather go and watch Red Sun ( 1971 ) , feature Charles Bronson as cowboy who have to team up with Samurai Toshiro Mifume to retrieve a samurai sword from bad - guy Alan Delon . -PRON- pretty much how to do -PRON- right and where Kabuto go wrong .   so , even though the film be a mere 100 minute , -PRON- seem like a much long film .   the reason -PRON- give this a honourable 4/10 point instead of 3/10 : first time -PRON- see this film , -PRON- see -PRON- in the german synchronize version . in this version , Kosugi can actually be understand . -PRON- must admit that -PRON- \' Engrish \' be at time funny but get tiresome after about 30 minute .',
#  'the ultimate goal of Big Brother , that -PRON- know what to think before -PRON- think -PRON- , have be realize . be -PRON- some kind of miracle , or sinister joke , that people don mental straight jacket of -PRON- own volition , twist -PRON- into contorted shape , and grin like ape ? movie , art , no longer risk the unknown , but be forgone conclusion , drain of life .   " the Notorious Bettie Page " be a bland case history , fit for a freshman college feminism course . -PRON- lesson be schematic , right - angle and linear : " see how woman be objectify , exploit , abuse , then toss on the trash heap , by a male - dominate society . "   Bettie Page , supposedly , be the " pin - up queen of the 1950 \'s , " the ass million of man ejaculate to . ( all reviewer repeat that phrase , " pin - up queen of the 1950 \'s , " like a choir of monkey . ) -PRON- history as an american sex bomb be familiar : southern , abuse by -PRON- father , rape , etc . in this movie -PRON- be a naïf , an innocent unaware of the prurient interest -PRON- serve and shamelessly profit from . although -PRON- believe in Jesus , -PRON- enjoy frolic nude before a camera lens -- just the wholesome girl - next - door sex - slave american male supposedly fantasize .   from the mouth of writer - director Mary Harron -PRON- , Oxford - educate and ex - punker ( do -PRON- smell the combined rot of privilege and " hipness " as -PRON- do ? ) : " -PRON- feel that without feminism , -PRON- would not be do this . ... -PRON- do not make feminist film in the sense that -PRON- do not make anything ideological . but -PRON- do find that woman get -PRON- film better . " what a cozy clique .   the movie merely go through the motion of tell the story of a human life , -PRON- be subject and purpose have be eulogize and inter well before the movie begin . Ms. Page have a boyfriend , but -PRON- be show next to nothing about -PRON- relationship . in fact , there be no intimate or detailed relationship in the film .    one can not ignore -PRON- smug simplicity . in New York , where Ms. Page try -PRON- good to fit into and appease a man \'s world , let -PRON- be tie up in the rope of bondage and tightly lace into the black leather boot and bodice of S & M , the movie be black and white . but down in Miami , where -PRON- go to get away from -PRON- all , gleefully take off -PRON- clothe , and be photograph by a " liberated " female , the movie turn into color .   like hell Harron do not " make feminist film , " do not " make anything ideological . " ideology have become so internalized , so assume , so program , that -PRON- be almost invisible . Big Brother must be smile .',
# ...
#  'Dennis Hopper be without a doubt one of the fine underrated american actor of -PRON- time , and -PRON- be interesting to see how -PRON- would play out -PRON- role as a cop on the case of a child serial killer . Most movie Hopper have always play to psychotic menace threaten to blow up stuff or go on a killing spree , but in this movie , Hopper try -PRON- good to keep that intensity and emotion while carry a shield . once -PRON- get into the plot of the movie , -PRON- be hook , but -PRON- be just the little thing that ultimately murder the film .   the concept of the film be great - not only be the cop on the move of catch the killer , but -PRON- get a chance to see how the gangster operate in catch the killer . the subplot of the football stadium be kinda ridiculous , but necessary to involve the gangster in the killer hunt .   that be about all that be good -PRON- can say about the film . although Hopper do try to act like a tough , experienced street smart cop , -PRON- can not help but feel -PRON- acting be below par , and there be not enough conviction that -PRON- be truly attach to the case . the directing be also terrible - -PRON- do not have the feel of a true film , but rather a tv - movie production . this be most evident when the gangster meet for the first time to form an elite team to hunt the killer down . when the lead gangster shoot the other mouthy gangster in slow motion , the acting be weak , predictable and terribly unexciting . that be when -PRON- know that 1st of all , the action be go to be atrocious .   the angling of the camera be amateurish , and the recall scene or haunt image of the killer \'s little sister have no true distinctive effect . if -PRON- be suppose to be scary , -PRON- be not . everyone \'s acting be terrible , and even for Hopper , -PRON- do not feel for -PRON- character , and -PRON- just do not really care too much about -PRON- relationship with -PRON- daughter .   the final thing that bother -PRON- the most be the swat team . once -PRON- see the swat team in action , -PRON- be think , finally , something good . but -PRON- be wrong . 1st of all , the entire swat team consist of 4 guy . that be just impossible . 2nd of all , apparently the swat team have no training whatsoever because many time in the film -PRON- carry -PRON- HKA4 submachine gun with one hand . have the killer be hide near the staircase with a shotgun , these 4 idiot would have be blow to bit because -PRON- be not even aim at anything or pay close attention . -PRON- should have have both hand on the gun aim forward , but -PRON- just look like -PRON- be not take the job seriously and be just flaunt around . 3rd , SWAT team member do not yell out command such as " keep -PRON- eye open , watch out for yourself , be -PRON- good to go ... etc . " in reality , -PRON- use hand signal or have radio . but -PRON- be literally yell at each other - how be -PRON- suppose to catch the killer when -PRON- can hear -PRON- be come ? ? ? and to top -PRON- all off , these guy have no plan - apparently -PRON- be just run up and down go on a wild turkey chase . eventually -PRON- end up do nothing . that be the last straw . -PRON- be no expert on special force , but basically what -PRON- have just outline , be pretty common sense . when the audience know the movie be terrible , the action pretty much become the life - saver of the movie - when -PRON- can not even make an effort to make the action great , the movie be lose .   -PRON- give 2 star for the concept , but the rest can not be credit . if -PRON- want to watch a crime thriller , do not bother with this one . there be plenty of crime in the movie - but -PRON- have the lack of thrill .',
#  "that hilarious line be typical of what these naughty sister say . ( -PRON- be funny on -PRON- own term and pretty funny unintentionally , too . ) only two of the sister be really bad . boy , be -PRON- bad , too ! one be give to pinup pose and salacious comment where e'er -PRON- go . the other be get up to look like Marilyn Monroe . -PRON- have those sensual , slightly part lip . and , not to give anything away , -PRON- be even more bad than the other .   all three sister be play by starlet . the man who stumble into -PRON- life be play by John Bromfield . -PRON- have something of a career .   this look today like possibly the first mainstream soft - core porn ever market . well , of course not the first but the raciest at that time .   the girl wear as little as possible and let -PRON- not forget about the female audience member : Bromfield be show shave with an electric razor -- whose fetish be this ? -- bare - cheste . -PRON- also be show sop wet in a swimsuit .   there be a real plot here , too : the girl ' family , see , be curse . -PRON- be prone to suicide -- or dramatic death that can be make to seem like suicide .   the movie be not bad . -PRON- truly do not know where -PRON- be show . maybe -PRON- be make for drive - in . somehow , and -PRON- could be wrong , -PRON- feel that the typical male audience be not the primary target here . the woman be scantily dress . -PRON- often resemble lurid cover of mag like Police detective or jacket of dime novel .   but the guy seem to be the central focus . not everyone in the movie like -PRON- , but all the girl love -PRON- . and -PRON- think the audience be mean to also .   -PRON- be lot of fun -- and on -PRON- own term , too .",
#  'this be a true " 80 \'s movie " : back then -PRON- make maybe 100 time more movie than nowadays , and that make many of -PRON- quite interesting ... -PRON- be a cultural phenomenon , that do not exist anymore . nowadays maybe the same kind of people that would have make cheap " straight - to - video"-movie in the eighty , be do cheap porn . porn seem to sell . anyway , this be above the medium trash - movie level : -PRON- have good&fascinate story , and -PRON- be quite well make -PRON- think . in one scene -PRON- can even see the microphone swinge on the upper edge of the picture . of course there be also little cameo by Ozzy and Gene Simmons , but -PRON- do not very much contribute to the film " success " , although -PRON- be good in -PRON- small role . the monster , heavy - singer " Sammi Curr " , look really terrible , especially when -PRON- be singe . one of the scary monster -PRON- have see in horror flick . -PRON- may have nightmare of -PRON- next night . not recommend for intellectual movie lover .',
#  'this be a must - see documentary movie for anyone who fear that modern youth have lose -PRON- taste for real - life adventure and -PRON- sense of morality . Darius go West be an amazing roller - coaster of a story . -PRON- live the life of Darius and the crew as -PRON- embark on the journey of a lifetime . Darius have Duchenne Muscular Dystrophy , a disease which affect all the muscle in -PRON- body . -PRON- be confine to a wheelchair , and need round - the - clock attention . so how could this crew of young friend possibly manage to take -PRON- on a 6,000 mile round - trip to the West Coast and back ? watch the movie and experience the up and down of this great adventure - laugh and cry with the crew as -PRON- cope with unimaginable challenge along the way , and enjoy the final triumph when -PRON- arrive back three week later in -PRON- home town to a rapturous reception and some great surprise !',
#  "a boy and a girl be chase by a local warrior because the boy kill ( by accident ) the warrior father ( or whoever -PRON- be ) . and -PRON- travel through the nature of Africa 's most ruff area .   the acting in this movie be not that good ( except for that elephant kid ) . but -PRON- be a very good adventure and -PRON- be not very censor , there be some blood , flesh and nudity ( which lighten up the movie a bit ) .   -PRON- give this movie a 7 because of -PRON- be picture of the african nature and -PRON- be action .",
#  "though -PRON- can not claim to be a comic book fanatic , -PRON- have read -PRON- share , so -PRON- guess -PRON- be part of the audience of this film , and -PRON- be not disappointed . -PRON- do run out of steam near the end , -PRON- be almost overflow with idea , and -PRON- seem like Lena Olin , one of -PRON- favorite actress , be leave on the cutting room floor . also , a little of Hank Azaria 's Blue Raja can go a long way . still , -PRON- be easy to forgive all of these fault when -PRON- have a film which be this much fun . all the actor seem to be have a blast with -PRON- role , especially William H. Macy as the straight - arrow Shoveler , and Janeane Garofalo as the Bowler . and unlike some , -PRON- find the design of the city to make the joke even funny . -PRON- also like how disco be the music of choice of the bad guy ; somehow , -PRON- seem appropriate .",
#  '-PRON- once promise never to walk out of any film ( a personal policy that make -PRON- suffer through the most different kind of dreck , such as Rambo 3 , Baise Moi , Deep Impact ) - but Mr. Seidl almost succeed . hundstage be a truly awful experience . anyone who see this movie will think that Austrians be a miserable , pathetic bunch of retard . -PRON- show a world where love and humanity do not exist , a world where people humiliate each other only for one reason - to distract from -PRON- own miserable existence . by choose a documentary - like style with non - professional actor ( most of -PRON- look like straight from the imagination of austrian shock - cartoonist Deix ) director Seidl want to make -PRON- believe that this be real life in austrian ( european ? western ? ) suburb . the viewer be confront with depiction of sex orgy , violence against woman and handicapped people , madness and degradation . but this be not social criticism . this be just pure shock without any aesthetic value . instead -PRON- get bad acting , bad cinematography , bad filmmaking . if anybody need a film like this to realize that there be thing wrong in -PRON- society then this person must have walk through life with close eye . this be pseudo - social criticism with a sledge hammer . and -PRON- look down on people in a disgustingly condescending way . -PRON- show ugly people - that be not the reason why -PRON- hate -PRON- . but -PRON- depict average people in an ugly , misanthropic way . and this be why this film be truly despicable .',
#  "the Woman in Black ( 1989 ) be a tv adaptation of Susan Hill 's modern classic ghost story , publish only a few year earlier than the film be make . sadly , this film have not be release on dvd , and as far as -PRON- be aware -PRON- have be delete on VHS . -PRON- be availability be in direct contrast to -PRON- be popularity amongst those in the know about horror film . the story revolve around event in a seaside community in the early 20th century where a young solicitor be send by -PRON- firm to conclude the affair of a recently deceased widow , who die on -PRON- isolate marshland estate . what -PRON- think would be a routine and probably tedious task turn into a nightmare as -PRON- discover that the old woman be haunt to -PRON- death , and that the ghost of -PRON- past be not content to rest . the story be tell in a subtle but concise way , never be self - indulgent , flashy or over - expositional . the obviously tight budget may have contribute to the no - nonsense approach , but -PRON- be just what the story need , and why -PRON- work so well . -PRON- be what -PRON- do not see that scare . have say that , there be one particularly terrifying scene that rely on the visual , and -PRON- work to perfection . -PRON- watch this film during the day , and -PRON- still give -PRON- nightmare nearly a week later . if -PRON- love be terrify , do what -PRON- must to get hold of and watch a copy of the Woman in Black .",
#  'this documentary be incredibly think - provoking , bring -PRON- in to the life of two long - time lover who be in the final stage of AIDS . the past footage of -PRON- twenty - some - odd year together really bring -PRON- final moment home .   if this movie do not make -PRON- feel the pain and agony of these two fascinating people , -PRON- do not have a heart .',
#  'Ben & Arthur COULD have be a 10 . Sam Mraovich write , direct , stare , and produce this movie . Sam should have give -PRON- idea to a good writer , director , and leave the acting to somebody who could act . this be a good example of one person control the whole production . there be nobody to tell -PRON- , " Sam this be bad , really bad " .   Jamie Brett Gabel \'s acting be the only good point , but -PRON- could have be so much well with a good director , and well actor to work with .    this movie be so bad i think Sam Mraovich should be tie to a chair and make to watch this movie ( twice ) . the acting and direction be so bad , this movie be turn into a comedy . -PRON- just have to laugh , and in the wrong place .    a second good point .... this would make a great date movie . after the first two minute -PRON- would quit watch the movie and pay more attention to -PRON- date !',
#  '-PRON- be very skeptical about sacrifice -PRON- precious time to watch this film . -PRON- do not enjoy the first one at all , and the last Jean Claude Van Damme film -PRON- like be Blood Sports ! after manage to sit through -PRON- all ? avoid , avoid , avoid ! !',
#  'for quite a long time in -PRON- life , -PRON- either do not like this film , or -PRON- like this film but not as much as many more . -PRON- watch -PRON- recently ( at a sleepover , funnily enough ) and -PRON- like -PRON- more than -PRON- have do since -PRON- be under 6 or something . -PRON- now appreciate -PRON- more , as -PRON- do with a few other Disney classic that -PRON- have watch recently ( include " Sleeping Beauty " and " Pinnochio " or however -PRON- spell -PRON- ) .    -PRON- now very much appreciate the animation , the clever " Disney " plot turn , the humour from the mouse , the emotion express and the plot . the animation be very well do , often -PRON- seem -PRON- be wherever the other character be , watch -PRON- . the animation also do well portray the style of the background , include the town ( which be show twice briefly ) . Disney change this from the original fairy tale in a surprisingly good way , inject clever plot turn , such as the mouse make the clothe and the key part ( usually -PRON- do not like Disney film very much if -PRON- be not that similar to the original story , but with this -PRON- be not overly bother . -PRON- feel -PRON- make necessary change to make this a good Disney film . often -PRON- do not think Disney change the book in a good way in some of -PRON- film ) .    -PRON- know the story already , Cinderella be a girl work for -PRON- horrible stepmother and stepsister . -PRON- go to a ball with the help of -PRON- fairy godmother and lose a glass slipper ...   this be a film very much to be watch with other people . immediate family be not good enough . to enjoy this , -PRON- recommend -PRON- watch -PRON- with friend ( and immediate family , if -PRON- like . :-) ) .    -PRON- recommend this to people who like Disney at least a little bit , people who like fairy tale and for people who like mouse . enjoy ! :-)',
#  'the shame of -PRON- ! there -PRON- be , comfortable in the arm chair with a beer and a bag of popcorn , bouyant in the hope of another splendid Muppet night of entertainment . what do -PRON- get ? disappoint ! how can the muppet go from the sublime Christmas Carol to this ? the humour be dreadful , the song be bad than Country and Western ( and that be say something ) and the plot be as confused and poor as Blind Pew . -PRON- think the main problem be that -PRON- bite off too much in attempt Treasure Island . a short tale , such as Christmas Carol , be perfect because -PRON- can weave the Muppet high jink around -PRON- .... here the need to drag the plot along stop all the fun . where do the muppet go next ? how about Muppets Wizard of Oz ?']

# %% [markdown]
# Весь этот процесс очень долгий, поэтому я предподсчитал всё.

# %%
import pickle

with open('train_docs.pkl', 'rb') as f:
    train_docs = pickle.load(f)
    
with open('test_docs.pkl', 'rb') as f:
    test_docs = pickle.load(f)

# %% [markdown]
# **Задание** Сделайте классификатор на лемматизированных текстах.
#
# Более простой способ нормализации слов - использовать стемминг. Он немного тупой, не учитывает контекст, но иногда оказывается даже эффективнее лемматизации - а, главное, быстрее.
#
# По сути это просто набор правил, как обрезать слово, чтобы получить основу (stem):

# %%
from nltk import PorterStemmer

stemmer = PorterStemmer()
review_stem = [' '.join([stemmer.stem(str(token)) for token in doc]) for doc in nlp.pipe(train_df.review.values)]
train_df_lemma_stem = train_df_lemma.copy()
train_df_lemma_stem['review_stem'] = review_stem 
# print(stemmer.stem('become'))
# print(stemmer.stem('becomes'))
# print(stemmer.stem('became'))
train_df_lemma_stem
# Out:
#        is_positive  ...                                        review_stem
# 0                0  ...  dreamgirl , despit it fist of toni win in an i...
# 1                0  ...  thi show come up with interest locat as fast a...
# 2                1  ...  I simpli love thi movi . I also love the ramon...
# 3                0  ...  spoiler ahead if you want to call them that .....
# 4                1  ...  My all - time favorit movi ! I have seen mani ...
# ...            ...  ...                                                ...
# 24995            1  ...  I am a big fan of the movi , but not for the u...
# 24996            0  ...  I 'm not go to bother with a plot synopsi sinc...
# 24997            0  ...  thi movi . . . I do n't know . whi they would ...
# 24998            1  ...  saw thi film on dvd yesterday and wa gob - sma...
# 24999            0  ...  thi wa a disappoint - none of the nuanc of the...
#
# [25000 rows x 4 columns]

# %% [markdown]
# **Задание** Попробуйте вместо лемм классифицировать основы.

# %%
vectorizer = TfidfVectorizer(ngram_range=(2, 6), max_features=20000, analyzer='char')
classifier = LogisticRegression()

model1 = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model1.fit(train_df_lemma_stem['review_lemma'], train_df_lemma_stem['is_positive'])

eval_model(model1, test_df)
# Out:
# Test accuracy = 85.64%

# %%
vectorizer = TfidfVectorizer(ngram_range=(2, 6), max_features=20000, analyzer='char')
classifier = LogisticRegression()

model2 = Pipeline([
    ('vectorizer', vectorizer),
    ('classifier', classifier)
])

model2.fit(train_df_lemma_stem['review_stem'], train_df_lemma_stem['is_positive'])

eval_model(model2, test_df)
# Out:
# Test accuracy = 86.24%

# %% [markdown]
# ### NER
#
# В текстах рецензий очень много именованных сущностей. Вот, например:

# %%
displacy.render(docs[0], style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dreamgirls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , despite its fistful of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tony
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wins in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     an incredibly weak year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Broadway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# , has never been what one would call a jewel in the crown of stage musicals. However, that is not to say that in the right cinematic hands it could not be fleshed out and polished into something worthwhile on-screen. Unfortunately, what transfers to the screen is basically a slavishly faithful version of the stage hit with all of its inherent weaknesses intact.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# , the score has never been one of the strong points of this production and the film does not change that factor. There are lots of songs (perhaps too many?), but few of them are especially memorable. The closest any come to catchy tunes are the title song and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One Night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  Only - the much acclaimed And I Am Telling You That I Am Not Going is less a great song than it is a dramatic set piece for the character of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Effie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jennifer Hudson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ). The film is slick and technically well-produced, but the story and characters are surprisingly thin and lacking in any resonance. There is some interest in the opening moments, watching
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jamie Foxx's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Svengali-like manager manipulate his acts to the top, but that takes a back seat in the latter portion of the film, when the story conveniently tries to cast him as a villain, despite his having been right from a business stand-point for a good majority of the film.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Beyonce Knowles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  is lovely and sings her songs perfectly well, but is stuck with a character who is basically all surface glitz.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anika Noni Rose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  as the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     third
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  member of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dreamgirls
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  trio literally has nothing to do for the entire film.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eddie Murphy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  acquits himself well as a singer obviously based on
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James Brown
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , but the role is not especially meaty and ultimately has little impact.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Foxx
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  would seem ideal casting, but he seems oddly withdrawn and bored. The film's biggest selling point is surely former
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American Idol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  contestant/
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Oscar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  winner
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jennifer Hudson
#     <span style="font-size: 0.8em; font-wei

# %% [markdown]
# Вообще говоря, почему вдруг какой-нибудь Депп должен нести семантическую окраску? Однако оказывается, что классификатор выучивает, что какие-то имена чаще в положительных рецензиях - или наоборот. Это похоже на переобучение - почему бы не попробовать вырезать сущности?
#
# **Задание** Удалите из текстов какие-то из сущностей, пользуясь координатами из запикленных файлов. Описание сущностей можно посмотреть [здесь](https://spacy.io/api/annotation#named-entities). Запустите классификатор.

# %% [markdown]
# ## Включаем дип лёрнинг

# %% [markdown]
# Мы тут пришли deep learning'ом заниматься, а делаем почему-то модель на логистической регрессии. Как так?
#
# Попробуем запустить относительно стандартную модель для классификации текстов - сверточная сеть поверх словных эмбеддингов.
#
# Разбираться, что это за зверь, будем на следующих занятиях, а пока будем просто им пользоваться :)
#
# Каждое предложение нужно представлять набором слов - и сразу же начинаются проблемы. Во-первых, как ограничить длину предложения?
#
# Прикинем по гистограмме, какая длина нам подходит:

# %%
train_df['review']
# Out:
# 0        Dreamgirls, despite its fistful of Tony wins i...
# 1        This show comes up with interesting locations ...
# 2        I simply love this movie. I also love the Ramo...
# 3        Spoilers ahead if you want to call them that.....
# 4        My all-time favorite movie! I have seen many m...
#                                ...
# 24995    I am a big fan of the movie, but not for the u...
# 24996    I'm not going to bother with a plot synopsis s...
# 24997    This movie . . . I don't know. Why they would ...
# 24998    Saw this film on DVD yesterday and was gob-sma...
# 24999    This was a disappointment - none of the nuance...
# Name: review, Length: 25000, dtype: object

# %% [raw]
# %matplotlib inline
# import matplotlib.pyplot as plt
#
# _, _, hist = plt.hist(train_df.review.apply(lambda text: len(text.split())), bins='auto')
# hist

# %% [markdown]
# Кроме этого, нужно перенумеровать как-то слова.

# %%
from collections import Counter

words_counter = Counter((word for text in train_df.review for word in text.lower().split()))

word2idx = {
    '': 0,
    '<unk>': 1
}
for word, count in words_counter.most_common():
    if count < 10:
        break
        
    word2idx[word] = len(word2idx)
    
print('Words count', len(word2idx))
# Out:
# Words count 26783

# %% [markdown]
# **Задание** Сконвертируйте данные

# %%
def convert(texts, word2idx, max_text_len):
    data = np.zeros((len(texts), max_text_len), dtype=np.int)
    
    for inx, text in enumerate(texts):
        result = []
        for word in text.split():
            if word in word2idx:
                result.append(word2idx[word])
        padding = [0]*(max_text_len - len(result))
        data[inx] = np.array(padding + result[-max_text_len:], dtype=np.int)
    return data

X_train = convert(train_df.review, word2idx, 1000)
X_test = convert(test_df.review, word2idx, 1000)

# %% [markdown]
# Поставим учиться модельку на keras.
#
# *Напоминание*: на keras, чтобы обучить модель, нужно
# 1. Определить модель, например:
# ```python
# model = Sequential()
# model.add(Dense(1, activation='sigmoid', input_dim=NUM_WORDS))
# ```
# 2. Задать функцию потерь и оптимизатор:
# ```python
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# ```
#
# 3. Запустить обучение:
# ```python
# model.fit(X_train, y_train,
#           batch_size=32,
#           epochs=3,
#           validation_data=(X_test, y_test))
# ```
#
# В NLP чаще всего ставятся задачи классификации, поэтому нужно запомнить такие функции потерь:
#
# *   **categorical_crossentropy** - для многоклассовой классификации, в качестве меток должны передаваться one-hot-encoding вектора
# *   **sparse_categorical_crossentropy** - аналогично предыдущему, но в качестве меток нужно передавать просто индексы соответствующих классов
# *   **binary_crossentropy** - для бинарной классификации
#
#
# В качестве оптимизатора обычно используют `sgd` или `adam`.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.6.0'

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalMaxPooling1D, Dropout

# %%
model = Sequential([
    Embedding(input_dim=len(word2idx), output_dim=64, input_shape=(X_train.shape[1],)),
    GlobalMaxPooling1D(),
    Dense(units=10, activation='relu'),
    Dense(units=10, activation='relu'),
    
    Dense(units=1, activation='sigmoid')
])

model.summary()
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1000, 64)          1714112
# _________________________________________________________________
# global_max_pooling1d (Global (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 10)                650
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 1,714,883
# Trainable params: 1,714,883
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, train_df.is_positive, batch_size=128, epochs=10, 
          validation_data=(X_test, test_df.is_positive))
# Out:
# Epoch 1/10
# 196/196 [==============================] - 7s 19ms/step - loss: 0.6325 - accuracy: 0.6599 - val_loss: 0.5316 - val_accuracy: 0.8091
# Epoch 2/10
# 196/196 [==============================] - 3s 17ms/step - loss: 0.4292 - accuracy: 0.8673 - val_loss: 0.3523 - val_accuracy: 0.8678
# Epoch 3/10
# 196/196 [==============================] - 3s 17ms/step - loss: 0.2094 - accuracy: 0.9306 - val_loss: 0.3063 - val_accuracy: 0.8706
# Epoch 4/10
# 196/196 [==============================] - 3s 17ms/step - loss: 0.1148 - accuracy: 0.9655 - val_loss: 0.3242 - val_accuracy: 0.8720
# Epoch 5/10
# 196/196 [==============================] - 3s 17ms/step - loss: 0.0587 - accuracy: 0.9868 - val_loss: 0.3684 - val_accuracy: 0.8683
# Epoch 6/10
# 196/196 [==============================] - 3s 17ms/step - loss: 0.0302 - accuracy: 0.9955 - val_loss: 0.4147 - val_accuracy: 0.8652
# Epoch 7/10
# 196/196 [==============================] - 3s 17ms/step - loss: 0.0181 - accuracy: 0.9979 - val_loss: 0.4430 - val_accuracy: 0.8653
# Epoch 8/10
# 196/196 [==============================] - 3s 17ms/step - loss: 0.0138 - accuracy: 0.9982 - val_loss: 0.4670 - val_accuracy: 0.8642
# Epoch 9/10
# 196/196 [==============================] - 3s 17ms/step - loss: 0.0112 - accuracy: 0.9984 - val_loss: 0.4872 - val_accuracy: 0.8640
# Epoch 10/10
# 196/196 [==============================] - 3s 17ms/step - loss: 0.0098 - accuracy: 0.9986 - val_loss: 0.5021 - val_accuracy: 0.8631

# %% [markdown]
# **Задание** Подсчитайте качество модели на тесте
